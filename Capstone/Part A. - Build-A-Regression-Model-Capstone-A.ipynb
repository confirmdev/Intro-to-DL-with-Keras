# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Regression Models with Keras</font></h1>

# %% [markdown]
# ## Capstone Project for Introduction to Deep Learning with Keras

# %% [markdown]
# In this project, you will build a regression model using the Keras library to model the same data about concrete compressive strength that we used in labs 3. For your convenience, the data can be found here again: https://cocl.us/concrete_data. To recap, the predictors in the data of concrete strength include:
#
# Cement
# Blast Furnace Slag
# Fly Ash
# Water
# Superplasticizer
# Coarse Aggregate
# Fine Aggregate
#
#
#
# The four parts of the capstone:
# <h5> A. Build a baseline model</h5>
# <h5> B. Normalize the data </h5>
# <h5> C. Increate the number of epochs </h5>
# <h5> D. Increase the number of hidden layers </h5>

# %% [markdown]
# <h2>Regression Models with Keras</h2>
#
# <h3>Capstone Project<h3>
# <h5> 1. Download and Clean dataset</h5>
# <h5> 2. Build a Regression Model with Keras </h5>
# <h5> 3. Train and Test the Network. </h5>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
# Download Data
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
# Checking size of data
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
# Checking for Null values
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # input data or predictors drawn form data
target = concrete_data['Strength'] # set target to strenght

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
#

# %% [markdown]
# Let's save the number of predictors to _n_cols_ since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors
print(n_cols)
# Out:
# 8

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_splithelper function from Scikit-learn

# %%
from sklearn.model_selection import train_test_split
predictors_train, predictors_test, target_train, target_test = train_test_split( predictors, target, test_size=0.3, random_state=4)
print ('Train set:', predictors_train.shape,  target_train.shape)
print ('Test set:', predictors_test.shape,  target_test.shape)
# Out:
# Train set: (721, 8) (721,)
# Test set: (309, 8) (309,)

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.
#
# One hidden layer of 10 nodes, and a ReLU activation function

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# %whos
# Out:
# Variable                Type          Data/Info
# -----------------------------------------------
# Dense                   type          <class 'keras.layers.core.Dense'>
# Sequential              type          <class 'keras.models.Sequential'>
# concrete_data           DataFrame           Cement  Blast Furna<...>\n[1030 rows x 9 columns]
# concrete_data_columns   Index         Index(['Cement', 'Blast F<...>],\n      dtype='object')
# keras                   module        <module 'keras' from '/ho<...>kages/keras/__init__.py'>
# l                       list          n=27
# mean_squared_error      function      <function mean_squared_error at 0x7fd0ac728b70>
# model                   Sequential    <keras.models.Sequential <...>object at 0x7fd00c6778d0>
# mse                     float64       119.9451045159662
# n_cols                  int           8
# np                      module        <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# pd                      module        <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# pred                    ndarray       309x1: 309 elems, type `float32`, 1236 bytes
# predictions             ndarray       3x1: 3 elems, type `float32`, 12 bytes
# predictors              DataFrame           Cement  Blast Furna<...>\n[1030 rows x 8 columns]
# predictors_norm         DataFrame             Cement  Blast Fur<...>\n[1030 rows x 8 columns]
# predictors_test         DataFrame          Cement  Blast Furnac<...>n\n[309 rows x 8 columns]
# predictors_train        DataFrame          Cement  Blast Furnac<...>n\n[721 rows x 8 columns]
# regression_model        function      <function regression_model at 0x7fd016402a60>
# results                 float64       217.61868602172456
# target                  Series        0       79.99\n1       61<...>gth: 1030, dtype: float64
# target_test             Series        522    44.52\n701    50.5<...>ngth: 309, dtype: float64
# target_train            Series        401    58.52\n288    45.3<...>ngth: 721, dtype: float64
# time                    int           27
# times                   int           50
# train_test_split        function      <function train_test_split at 0x7fd0ae018e18>

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## 2. Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Train the model on the training data using 50 epochs.

# %%
# fit the model
model.fit(predictors, target, validation_split=0.3, epochs=50, verbose=2)
# Out:
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 19679.5107 - val_loss: 12132.9323
# Epoch 2/50
#  - 0s - loss: 7073.5429 - val_loss: 4020.2635
# Epoch 3/50
#  - 0s - loss: 2154.9625 - val_loss: 1661.2707
# Epoch 4/50
#  - 0s - loss: 1133.7264 - val_loss: 1308.6251
# Epoch 5/50
#  - 0s - loss: 1014.8811 - val_loss: 1232.1943
# Epoch 6/50
#  - 0s - loss: 967.0948 - val_loss: 1173.4271
# Epoch 7/50
#  - 0s - loss: 918.0373 - val_loss: 1120.7351
# Epoch 8/50
#  - 0s - loss: 871.6712 - val_loss: 1060.4884
# Epoch 9/50
#  - 0s - loss: 827.8394 - val_loss: 1007.1295
# Epoch 10/50
#  - 0s - loss: 786.1199 - val_loss: 956.3112
# Epoch 11/50
#  - 0s - loss: 746.8405 - val_loss: 899.2072
# Epoch 12/50
#  - 0s - loss: 709.6054 - val_loss: 852.7871
# Epoch 13/50
#  - 0s - loss: 675.1687 - val_loss: 809.5686
# Epoch 14/50
#  - 0s - loss: 643.9426 - val_loss: 765.9246
# Epoch 15/50
#  - 0s - loss: 613.3559 - val_loss: 722.1425
# Epoch 16/50
#  - 0s - loss: 586.8346 - val_loss: 684.9157
# Epoch 17/50
#  - 0s - loss: 559.7753 - val_loss: 645.5416
# Epoch 18/50
#  - 0s - loss: 536.7514 - val_loss: 612.7723
# Epoch 19/50
#  - 0s - loss: 515.9552 - val_loss: 575.2769
# Epoch 20/50
#  - 0s - loss: 493.1056 - val_loss: 549.9042
# Epoch 21/50
#  - 0s - loss: 473.6424 - val_loss: 519.3413
# Epoch 22/50
#  - 0s - loss: 456.7609 - val_loss: 487.0811
# Epoch 23/50
#  - 0s - loss: 439.6003 - val_loss: 467.3310
# Epoch 24/50
#  - 0s - loss: 422.7852 - val_loss: 438.9331
# Epoch 25/50
#  - 0s - loss: 408.6027 - val_loss: 415.2433
# Epoch 26/50
#  - 0s - loss: 395.7134 - val_loss: 397.4682
# Epoch 27/50
#  - 0s - loss: 383.0281 - val_loss: 374.9231
# Epoch 28/50
#  - 0s - loss: 368.9593 - val_loss: 357.9814
# Epoch 29/50
#  - 0s - loss: 357.6096 - val_loss: 336.5682
# Epoch 30/50
#  - 0s - loss: 347.3106 - val_loss: 320.0302
# Epoch 31/50
#  - 0s - loss: 337.6378 - val_loss: 301.5551
# Epoch 32/50
#  - 0s - loss: 328.1480 - val_loss: 292.7357
# Epoch 33/50
#  - 0s - loss: 318.7622 - val_loss: 273.0059
# Epoch 34/50
#  - 0s - loss: 310.7796 - val_loss: 262.0618
# Epoch 35/50
#  - 0s - loss: 302.8698 - val_loss: 246.9085
# Epoch 36/50
#  - 0s - loss: 295.0396 - val_loss: 241.2645
# Epoch 37/50
#  - 0s - loss: 287.3002 - val_loss: 222.1199
# Epoch 38/50
#  - 0s - loss: 282.5797 - val_loss: 213.8283
# Epoch 39/50
#  - 0s - loss: 274.1726 - val_loss: 205.5693
# Epoch 40/50
#  - 0s - loss: 267.5409 - val_loss: 198.3548
# Epoch 41/50
#  - 0s - loss: 261.9924 - val_loss: 188.2428
# Epoch 42/50
#  - 0s - loss: 256.4209 - val_loss: 180.5842
# Epoch 43/50
#  - 0s - loss: 250.2226 - val_loss: 172.0112
# Epoch 44/50
#  - 0s - loss: 245.1102 - val_loss: 167.2625
# Epoch 45/50
#  - 0s - loss: 240.1447 - val_loss: 162.1091
# Epoch 46/50
#  - 0s - loss: 235.0196 - val_loss: 156.6490
# Epoch 47/50
#  - 0s - loss: 230.8102 - val_loss: 148.8440
# Epoch 48/50
#  - 0s - loss: 225.6693 - val_loss: 147.6187
# Epoch 49/50
#  - 0s - loss: 221.8098 - val_loss: 135.7881
# Epoch 50/50
#  - 0s - loss: 219.3368 - val_loss: 142.9693

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(predictors_test, target_test, batch_size=128)
print("test loss, test acc:", results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print("Generate predictions for 3 samples")
predictions = model.predict(predictors_test[:3])
print("predictions shape:", predictions.shape)
# Out:
# Evaluate on test data
# 309/309 [==============================] - 0s 12us/step
# test loss, test acc: 217.61868602172456
# Generate predictions for 3 samples
# predictions shape: (3, 1)

# %% [markdown]
# ## 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.

# %%
from sklearn.metrics import mean_squared_error
times = 50
l = []

for time in range(times):
    print("Number of time: ", time+1)
    predictors_train, predictors_test, target_train, target_test = train_test_split( predictors, target, test_size=0.3, random_state=4)
    model.fit(predictors, target, validation_split=0.3, epochs=50, verbose=2)
    
    pred = model.predict(predictors_test)

    mse = mean_squared_error(target_test, pred)
    l.append(mse)
    print(" ")
# Out:
# Number of time:  1
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 126.8802 - val_loss: 73.7285
# Epoch 2/50
#  - 0s - loss: 125.5552 - val_loss: 73.3289
# Epoch 3/50
#  - 0s - loss: 125.6908 - val_loss: 73.2771
# Epoch 4/50
#  - 0s - loss: 127.7068 - val_loss: 76.5371
# Epoch 5/50
#  - 0s - loss: 130.5771 - val_loss: 73.5826
# Epoch 6/50
#  - 0s - loss: 125.0434 - val_loss: 72.9846
# Epoch 7/50
#  - 0s - loss: 124.1730 - val_loss: 77.7439
# Epoch 8/50
#  - 0s - loss: 129.4372 - val_loss: 76.7375
# Epoch 9/50
#  - 0s - loss: 125.7344 - val_loss: 73.3907
# Epoch 10/50
#  - 0s - loss: 125.5633 - val_loss: 74.5616
# Epoch 11/50
#  - 0s - loss: 126.3566 - val_loss: 73.1163
# Epoch 12/50
#  - 0s - loss: 126.0428 - val_loss: 73.5532
# Epoch 13/50
#  - 0s - loss: 127.1601 - val_loss: 73.9827
# Epoch 14/50
#  - 0s - loss: 128.1026 - val_loss: 73.0475
# Epoch 15/50
#  - 0s - loss: 127.6863 - val_loss: 72.7587
# Epoch 16/50
#  - 0s - loss: 129.4636 - val_loss: 95.7959
# Epoch 17/50
#  - 0s - loss: 132.4276 - val_loss: 79.6324
# Epoch 18/50
#  - 0s - loss: 127.2875 - val_loss: 79.0495
# Epoch 19/50
#  - 0s - loss: 126.2766 - val_loss: 73.0584
# Epoch 20/50
#  - 0s - loss: 125.9751 - val_loss: 78.0355
# Epoch 21/50
#  - 0s - loss: 130.1271 - val_loss: 75.3406
# Epoch 22/50
#  - 0s - loss: 126.4373 - val_loss: 73.1402
# Epoch 23/50
#  - 0s - loss: 127.1011 - val_loss: 72.7254
# Epoch 24/50
#  - 0s - loss: 125.2930 - val_loss: 72.9314
# Epoch 25/50
#  - 0s - loss: 125.9669 - val_loss: 73.0457
# Epoch 26/50
#  - 0s - loss: 125.5029 - val_loss: 76.4423
# Epoch 27/50
#  - 0s - loss: 126.8826 - val_loss: 73.6573
# Epoch 28/50
#  - 0s - loss: 126.0817 - val_loss: 73.0295
# Epoch 29/50
#  - 0s - loss: 125.8325 - val_loss: 74.4640
# Epoch 30/50
#  - 0s - loss: 127.5068 - val_loss: 73.7918
# Epoch 31/50
#  - 0s - loss: 125.4663 - val_loss: 74.5452
# Epoch 32/50
#  - 0s - loss: 125.5648 - val_loss: 73.6523
# Epoch 33/50
#  - 0s - loss: 125.8154 - val_loss: 73.2397
# Epoch 34/50
#  - 0s - loss: 126.2254 - val_loss: 74.2102
# Epoch 35/50
#  - 0s - loss: 126.6968 - val_loss: 78.3321
# Epoch 36/50
#  - 0s - loss: 129.3702 - val_loss: 83.1585
# Epoch 37/50
#  - 0s - loss: 124.9202 - val_loss: 73.8561
# Epoch 38/50
#  - 0s - loss: 125.8414 - val_loss: 74.3929
# Epoch 39/50
#  - 0s - loss: 126.1192 - val_loss: 73.4961
# Epoch 40/50
#  - 0s - loss: 125.0999 - val_loss: 74.1422
# Epoch 41/50
#  - 0s - loss: 126.2264 - val_loss: 72.8581
# Epoch 42/50
#  - 0s - loss: 126.2439 - val_loss: 73.9160
# Epoch 43/50
#  - 0s - loss: 125.3240 - val_loss: 73.3510
# Epoch 44/50
#  - 0s - loss: 125.4296 - val_loss: 73.3684
# Epoch 45/50
#  - 0s - loss: 125.7200 - val_loss: 72.8705
# Epoch 46/50
#  - 0s - loss: 126.4569 - val_loss: 74.3696
# Epoch 47/50
#  - 0s - loss: 125.4672 - val_loss: 73.3041
# Epoch 48/50
#  - 0s - loss: 124.9637 - val_loss: 73.0918
# Epoch 49/50
#  - 0s - loss: 125.6741 - val_loss: 73.7127
# Epoch 50/50
#  - 0s - loss: 125.2187 - val_loss: 72.9449
#
# Number of time:  2
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 127.5183 - val_loss: 74.7654
# Epoch 2/50
#  - 0s - loss: 126.5914 - val_loss: 73.5244
# Epoch 3/50
#  - 0s - loss: 127.1720 - val_loss: 77.5395
# Epoch 4/50
#  - 0s - loss: 126.0150 - val_loss: 73.0613
# Epoch 5/50
#  - 0s - loss: 126.5177 - val_loss: 72.7281
# Epoch 6/50
#  - 0s - loss: 125.1428 - val_loss: 75.4753
# Epoch 7/50
#  - 0s - loss: 128.1532 - val_loss: 73.2348
# Epoch 8/50
#  - 0s - loss: 125.4603 - val_loss: 81.8418
# Epoch 9/50
#  - 0s - loss: 127.1498 - val_loss: 73.0556
# Epoch 10/50
#  - 0s - loss: 126.4964 - val_loss: 73.3701
# Epoch 11/50
#  - 0s - loss: 126.0870 - val_loss: 72.8057
# Epoch 12/50
#  - 0s - loss: 125.2690 - val_loss: 75.9665
# Epoch 13/50
#  - 0s - loss: 125.2867 - val_loss: 73.7960
# Epoch 14/50
#  - 0s - loss: 125.8453 - val_loss: 77.4201
# Epoch 15/50
#  - 0s - loss: 126.0724 - val_loss: 74.5918
# Epoch 16/50
#  - 0s - loss: 124.8067 - val_loss: 73.1923
# Epoch 17/50
#  - 0s - loss: 125.8887 - val_loss: 72.7782
# Epoch 18/50
#  - 0s - loss: 125.7084 - val_loss: 73.7003
# Epoch 19/50
#  - 0s - loss: 124.8318 - val_loss: 74.8557
# Epoch 20/50
#  - 0s - loss: 125.6196 - val_loss: 74.4176
# Epoch 21/50
#  - 0s - loss: 126.8662 - val_loss: 73.9007
# Epoch 22/50
#  - 0s - loss: 127.6767 - val_loss: 73.9019
# Epoch 23/50
#  - 0s - loss: 126.5087 - val_loss: 74.2982
# Epoch 24/50
#  - 0s - loss: 126.3895 - val_loss: 73.0875
# Epoch 25/50
#  - 0s - loss: 127.6416 - val_loss: 72.9170
# Epoch 26/50
#  - 0s - loss: 125.4755 - val_loss: 76.3264
# Epoch 27/50
#  - 0s - loss: 127.2669 - val_loss: 75.5516
# Epoch 28/50
#  - 0s - loss: 127.1452 - val_loss: 73.2511
# Epoch 29/50
#  - 0s - loss: 125.4616 - val_loss: 73.6584
# Epoch 30/50
#  - 0s - loss: 125.9474 - val_loss: 74.6659
# Epoch 31/50
#  - 0s - loss: 125.7718 - val_loss: 73.7961
# Epoch 32/50
#  - 0s - loss: 125.5020 - val_loss: 73.7560
# Epoch 33/50
#  - 0s - loss: 124.5376 - val_loss: 75.6428
# Epoch 34/50
#  - 0s - loss: 126.3230 - val_loss: 73.7107
# Epoch 35/50
#  - 0s - loss: 125.4025 - val_loss: 73.7597
# Epoch 36/50
#  - 0s - loss: 125.5472 - val_loss: 73.5785
# Epoch 37/50
#  - 0s - loss: 126.8863 - val_loss: 73.5104
# Epoch 38/50
#  - 0s - loss: 125.8181 - val_loss: 73.5604
# Epoch 39/50
#  - 0s - loss: 125.5175 - val_loss: 73.4162
# Epoch 40/50
#  - 0s - loss: 125.4923 - val_loss: 78.4436
# Epoch 41/50
#  - 0s - loss: 126.9534 - val_loss: 73.2743
# Epoch 42/50
#  - 0s - loss: 125.5607 - val_loss: 76.3182
# Epoch 43/50
#  - 0s - loss: 127.5035 - val_loss: 79.6939
# Epoch 44/50
#  - 0s - loss: 130.5850 - val_loss: 73.4094
# Epoch 45/50
#  - 0s - loss: 126.9667 - val_loss: 75.3357
# Epoch 46/50
#  - 0s - loss: 126.2696 - val_loss: 76.1829
# Epoch 47/50
#  - 0s - loss: 126.6593 - val_loss: 73.4797
# Epoch 48/50
#  - 0s - loss: 125.4908 - val_loss: 73.8771
# Epoch 49/50
#  - 0s - loss: 125.1436 - val_loss: 73.2235
# Epoch 50/50
#  - 0s - loss: 126.5542 - val_loss: 77.2933
#
# Number of time:  3
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 127.7169 - val_loss: 74.3971
# Epoch 2/50
#  - 0s - loss: 127.4729 - val_loss: 73.3952
# Epoch 3/50
#  - 0s - loss: 125.4817 - val_loss: 74.1084
# Epoch 4/50
#  - 0s - loss: 124.6911 - val_loss: 73.7152
# Epoch 5/50
#  - 0s - loss: 125.8899 - val_loss: 73.4065
# Epoch 6/50
#  - 0s - loss: 126.5125 - val_loss: 83.5720
# Epoch 7/50
#  - 0s - loss: 128.6057 - val_loss: 75.4493
# Epoch 8/50
#  - 0s - loss: 126.3101 - val_loss: 73.8966
# Epoch 9/50
#  - 0s - loss: 124.8539 - val_loss: 72.9017
# Epoch 10/50
#  - 0s - loss: 125.8587 - val_loss: 73.4955
# Epoch 11/50
#  - 0s - loss: 128.2060 - val_loss: 77.8402
# Epoch 12/50
#  - 0s - loss: 126.1490 - val_loss: 75.4586
# Epoch 13/50
#  - 0s - loss: 125.3746 - val_loss: 74.3819
# Epoch 14/50
#  - 0s - loss: 126.3052 - val_loss: 73.2454
# Epoch 15/50
#  - 0s - loss: 128.9930 - val_loss: 79.8680
# Epoch 16/50
#  - 0s - loss: 128.1640 - val_loss: 73.5039
# Epoch 17/50
#  - 0s - loss: 126.0817 - val_loss: 74.7409
# Epoch 18/50
#  - 0s - loss: 126.1633 - val_loss: 77.0901
# Epoch 19/50
#  - 0s - loss: 127.9193 - val_loss: 72.9627
# Epoch 20/50
#  - 0s - loss: 126.2209 - val_loss: 73.7614
# Epoch 21/50
#  - 0s - loss: 125.1848 - val_loss: 73.5006
# Epoch 22/50
#  - 0s - loss: 125.5294 - val_loss: 73.3508
# Epoch 23/50
#  - 0s - loss: 127.0482 - val_loss: 74.5030
# Epoch 24/50
#  - 0s - loss: 126.7195 - val_loss: 73.2918
# Epoch 25/50
#  - 0s - loss: 126.2934 - val_loss: 73.1663
# Epoch 26/50
#  - 0s - loss: 125.4260 - val_loss: 74.1973
# Epoch 27/50
#  - 0s - loss: 125.7167 - val_loss: 75.7121
# Epoch 28/50
#  - 0s - loss: 127.0169 - val_loss: 73.7775
# Epoch 29/50
#  - 0s - loss: 128.4375 - val_loss: 76.4037
# Epoch 30/50
#  - 0s - loss: 125.9670 - val_loss: 74.6105
# Epoch 31/50
#  - 0s - loss: 126.7987 - val_loss: 73.5587
# Epoch 32/50
#  - 0s - loss: 128.3565 - val_loss: 93.2134
# Epoch 33/50
#  - 0s - loss: 130.9729 - val_loss: 84.2437
# Epoch 34/50
#  - 0s - loss: 129.1247 - val_loss: 78.3878
# Epoch 35/50
#  - 0s - loss: 125.2852 - val_loss: 73.4446
# Epoch 36/50
#  - 0s - loss: 126.4806 - val_loss: 73.1782
# Epoch 37/50
#  - 0s - loss: 124.6819 - val_loss: 78.3341
# Epoch 38/50
#  - 0s - loss: 131.0191 - val_loss: 74.8548
# Epoch 39/50
#  - 0s - loss: 131.5076 - val_loss: 73.5641
# Epoch 40/50
#  - 0s - loss: 125.4745 - val_loss: 76.5581
# Epoch 41/50
#  - 0s - loss: 126.0940 - val_loss: 75.5530
# Epoch 42/50
#  - 0s - loss: 126.4976 - val_loss: 72.9839
# Epoch 43/50
#  - 0s - loss: 126.5784 - val_loss: 73.1043
# Epoch 44/50
#  - 0s - loss: 124.7208 - val_loss: 73.3375
# Epoch 45/50
#  - 0s - loss: 125.4359 - val_loss: 75.2727
# Epoch 46/50
#  - 0s - loss: 126.4478 - val_loss: 73.0254
# Epoch 47/50
#  - 0s - loss: 125.1630 - val_loss: 73.4883
# Epoch 48/50
#  - 0s - loss: 124.3721 - val_loss: 80.3044
# Epoch 49/50
#  - 0s - loss: 127.1563 - val_loss: 73.8212
# Epoch 50/50
#  - 0s - loss: 125.6937 - val_loss: 74.6288
#
# Number of time:  4
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 126.1458 - val_loss: 76.2419
# Epoch 2/50
#  - 0s - loss: 125.1898 - val_loss: 73.3463
# Epoch 3/50
#  - 0s - loss: 125.8873 - val_loss: 74.1268
# Epoch 4/50
#  - 0s - loss: 124.8775 - val_loss: 73.6902
# Epoch 5/50
#  - 0s - loss: 125.1914 - val_loss: 77.6136
# Epoch 6/50
#  - 0s - loss: 127.7031 - val_loss: 73.1537
# Epoch 7/50
#  - 0s - loss: 124.9498 - val_loss: 73.4338
# Epoch 8/50
#  - 0s - loss: 126.8619 - val_loss: 79.1925
# Epoch 9/50
#  - 0s - loss: 125.3160 - val_loss: 74.7975
# Epoch 10/50
#  - 0s - loss: 126.1000 - val_loss: 72.4804
# Epoch 11/50
#  - 0s - loss: 126.9240 - val_loss: 73.9635
# Epoch 12/50
#  - 0s - loss: 125.4090 - val_loss: 77.2232
# Epoch 13/50
#  - 0s - loss: 126.0104 - val_loss: 72.7553
# Epoch 14/50
#  - 0s - loss: 128.9021 - val_loss: 77.3478
# Epoch 15/50
#  - 0s - loss: 126.7122 - val_loss: 72.8473
# Epoch 16/50
#  - 0s - loss: 124.8513 - val_loss: 74.1441
# Epoch 17/50
#  - 0s - loss: 126.3281 - val_loss: 73.5370
# Epoch 18/50
#  - 0s - loss: 125.6804 - val_loss: 72.5897
# Epoch 19/50
#  - 0s - loss: 124.8775 - val_loss: 75.8016
# Epoch 20/50
#  - 0s - loss: 127.7289 - val_loss: 75.9200
# Epoch 21/50
#  - 0s - loss: 126.4925 - val_loss: 77.6571
# Epoch 22/50
#  - 0s - loss: 132.7829 - val_loss: 72.9292
# Epoch 23/50
#  - 0s - loss: 126.8962 - val_loss: 79.9536
# Epoch 24/50
#  - 0s - loss: 132.4859 - val_loss: 80.1517
# Epoch 25/50
#  - 0s - loss: 128.5194 - val_loss: 76.0609
# Epoch 26/50
#  - 0s - loss: 126.8331 - val_loss: 76.5749
# Epoch 27/50
#  - 0s - loss: 126.7675 - val_loss: 74.4972
# Epoch 28/50
#  - 0s - loss: 125.8109 - val_loss: 73.0584
# Epoch 29/50
#  - 0s - loss: 128.9376 - val_loss: 76.6336
# Epoch 30/50
#  - 0s - loss: 127.0827 - val_loss: 73.5559
# Epoch 31/50
#  - 0s - loss: 124.7490 - val_loss: 77.3678
# Epoch 32/50
#  - 0s - loss: 126.1714 - val_loss: 84.1684
# Epoch 33/50
#  - 0s - loss: 131.9192 - val_loss: 73.9571
# Epoch 34/50
#  - 0s - loss: 127.1247 - val_loss: 75.5810
# Epoch 35/50
#  - 0s - loss: 126.1353 - val_loss: 72.7768
# Epoch 36/50
#  - 0s - loss: 125.1661 - val_loss: 75.1650
# Epoch 37/50
#  - 0s - loss: 126.5064 - val_loss: 77.0203
# Epoch 38/50
#  - 0s - loss: 129.7949 - val_loss: 73.5402
# Epoch 39/50
#  - 0s - loss: 126.2719 - val_loss: 73.5722
# Epoch 40/50
#  - 0s - loss: 126.4301 - val_loss: 74.4527
# Epoch 41/50
#  - 0s - loss: 125.7816 - val_loss: 76.1002
# Epoch 42/50
#  - 0s - loss: 125.9636 - val_loss: 74.1092
# Epoch 43/50
#  - 0s - loss: 126.7777 - val_loss: 73.9986
# Epoch 44/50
#  - 0s - loss: 124.9445 - val_loss: 73.9329
# Epoch 45/50
#  - 0s - loss: 125.2477 - val_loss: 73.3406
# Epoch 46/50
#  - 0s - loss: 125.5926 - val_loss: 73.2514
# Epoch 47/50
#  - 0s - loss: 126.0648 - val_loss: 74.1000
# Epoch 48/50
#  - 0s - loss: 126.5846 - val_loss: 72.9563
# Epoch 49/50
#  - 0s - loss: 125.0039 - val_loss: 73.4947
# Epoch 50/50
#  - 0s - loss: 127.8012 - val_loss: 73.5139
#
# Number of time:  5
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 126.7564 - val_loss: 75.1041
# Epoch 2/50
#  - 0s - loss: 125.7373 - val_loss: 75.1264
# Epoch 3/50
#  - 0s - loss: 126.8513 - val_loss: 74.7440
# Epoch 4/50
#  - 0s - loss: 128.6675 - val_loss: 74.0060
# Epoch 5/50
#  - 0s - loss: 126.4026 - val_loss: 73.4970
# Epoch 6/50
#  - 0s - loss: 127.7804 - val_loss: 74.9874
# Epoch 7/50
#  - 0s - loss: 132.1286 - val_loss: 76.5562
# Epoch 8/50
#  - 0s - loss: 126.1089 - val_loss: 73.7827
# Epoch 9/50
#  - 0s - loss: 125.4932 - val_loss: 75.3962
# Epoch 10/50
#  - 0s - loss: 127.8117 - val_loss: 72.9565
# Epoch 11/50
#  - 0s - loss: 126.1836 - val_loss: 72.8423
# Epoch 12/50
#  - 0s - loss: 125.1058 - val_loss: 74.0692
# Epoch 13/50
#  - 0s - loss: 129.6793 - val_loss: 73.3409
# Epoch 14/50
#  - 0s - loss: 126.4655 - val_loss: 73.2847
# Epoch 15/50
#  - 0s - loss: 126.0598 - val_loss: 72.8119
# Epoch 16/50
#  - 0s - loss: 126.4349 - val_loss: 73.6180
# Epoch 17/50
#  - 0s - loss: 128.4355 - val_loss: 84.1767
# Epoch 18/50
#  - 0s - loss: 126.4347 - val_loss: 74.2765
# Epoch 19/50
#  - 0s - loss: 124.3215 - val_loss: 75.3939
# Epoch 20/50
#  - 0s - loss: 125.4105 - val_loss: 75.4875
# Epoch 21/50
#  - 0s - loss: 126.0211 - val_loss: 72.8990
# Epoch 22/50
#  - 0s - loss: 125.6591 - val_loss: 73.7017
# Epoch 23/50
#  - 0s - loss: 126.4200 - val_loss: 72.6050
# Epoch 24/50
#  - 0s - loss: 125.0278 - val_loss: 76.0408
# Epoch 25/50
#  - 0s - loss: 127.4203 - val_loss: 73.7687
# Epoch 26/50
#  - 0s - loss: 125.2519 - val_loss: 75.7541
# Epoch 27/50
#  - 0s - loss: 124.7056 - val_loss: 73.0135
# Epoch 28/50
#  - 0s - loss: 124.6348 - val_loss: 79.6092
# Epoch 29/50
#  - 0s - loss: 123.9339 - val_loss: 75.0370
# Epoch 30/50
#  - 0s - loss: 125.5740 - val_loss: 73.3344
# Epoch 31/50
#  - 0s - loss: 127.8358 - val_loss: 74.3534
# Epoch 32/50
#  - 0s - loss: 126.5672 - val_loss: 77.9533
# Epoch 33/50
#  - 0s - loss: 125.9871 - val_loss: 75.8269
# Epoch 34/50
#  - 0s - loss: 125.7538 - val_loss: 72.7049
# Epoch 35/50
#  - 0s - loss: 125.8559 - val_loss: 72.8825
# Epoch 36/50
#  - 0s - loss: 126.8341 - val_loss: 74.6950
# Epoch 37/50
#  - 0s - loss: 125.1168 - val_loss: 73.4343
# Epoch 38/50
#  - 0s - loss: 125.1780 - val_loss: 76.9058
# Epoch 39/50
#  - 0s - loss: 125.8668 - val_loss: 73.2934
# Epoch 40/50
#  - 0s - loss: 125.4609 - val_loss: 74.4431
# Epoch 41/50
#  - 0s - loss: 126.6073 - val_loss: 74.2103
# Epoch 42/50
#  - 0s - loss: 124.6358 - val_loss: 76.5314
# Epoch 43/50
#  - 0s - loss: 126.6224 - val_loss: 73.8197
# Epoch 44/50
#  - 0s - loss: 126.0041 - val_loss: 73.5234
# Epoch 45/50
#  - 0s - loss: 125.0063 - val_loss: 78.0392
# Epoch 46/50
#  - 0s - loss: 127.1621 - val_loss: 73.7730
# Epoch 47/50
#  - 0s - loss: 126.9035 - val_loss: 74.5523
# Epoch 48/50
#  - 0s - loss: 126.4483 - val_loss: 73.1641
# Epoch 49/50
#  - 0s - loss: 125.7446 - val_loss: 75.0841
# Epoch 50/50
#  - 0s - loss: 126.3972 - val_loss: 77.3944
#
# Number of time:  6
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 126.0750 - val_loss: 73.5040
# Epoch 2/50
#  - 0s - loss: 126.5406 - val_loss: 78.1870
# Epoch 3/50
#  - 0s - loss: 126.1806 - val_loss: 79.0595
# Epoch 4/50
#  - 0s - loss: 125.5423 - val_loss: 79.1955
# Epoch 5/50
#  - 0s - loss: 126.1210 - val_loss: 72.4302
# Epoch 6/50
#  - 0s - loss: 125.2253 - val_loss: 72.1897
# Epoch 7/50
#  - 0s - loss: 125.8443 - val_loss: 72.0110
# Epoch 8/50
#  - 0s - loss: 124.8182 - val_loss: 73.7916
# Epoch 9/50
#  - 0s - loss: 125.6254 - val_loss: 73.4440
# Epoch 10/50
#  - 0s - loss: 126.4691 - val_loss: 77.5105
# Epoch 11/50
#  - 0s - loss: 128.0007 - val_loss: 73.9201
# Epoch 12/50
#  - 0s - loss: 125.0308 - val_loss: 73.6615
# Epoch 13/50
#  - 0s - loss: 127.1065 - val_loss: 77.5053
# Epoch 14/50
#  - 0s - loss: 126.0582 - val_loss: 72.9479
# Epoch 15/50
#  - 0s - loss: 125.1780 - val_loss: 73.2934
# Epoch 16/50
#  - 0s - loss: 128.0741 - val_loss: 73.2217
# Epoch 17/50
#  - 0s - loss: 125.0356 - val_loss: 72.8296
# Epoch 18/50
#  - 0s - loss: 125.8972 - val_loss: 73.6651
# Epoch 19/50
#  - 0s - loss: 125.0962 - val_loss: 72.4417
# Epoch 20/50
#  - 0s - loss: 125.3258 - val_loss: 73.6339
# Epoch 21/50
#  - 0s - loss: 126.2050 - val_loss: 73.3236
# Epoch 22/50
#  - 0s - loss: 127.2840 - val_loss: 73.2335
# Epoch 23/50
#  - 0s - loss: 125.0065 - val_loss: 76.1222
# Epoch 24/50
#  - 0s - loss: 129.4636 - val_loss: 81.7930
# Epoch 25/50
#  - 0s - loss: 126.1098 - val_loss: 76.5308
# Epoch 26/50
#  - 0s - loss: 127.8701 - val_loss: 80.0968
# Epoch 27/50
#  - 0s - loss: 128.2590 - val_loss: 73.2159
# Epoch 28/50
#  - 0s - loss: 124.9041 - val_loss: 73.2462
# Epoch 29/50
#  - 0s - loss: 127.1328 - val_loss: 73.3595
# Epoch 30/50
#  - 0s - loss: 125.5229 - val_loss: 73.8966
# Epoch 31/50
#  - 0s - loss: 128.6486 - val_loss: 75.6517
# Epoch 32/50
#  - 0s - loss: 126.9871 - val_loss: 76.2439
# Epoch 33/50
#  - 0s - loss: 125.4275 - val_loss: 73.6472
# Epoch 34/50
#  - 0s - loss: 126.8928 - val_loss: 72.7608
# Epoch 35/50
#  - 0s - loss: 126.4778 - val_loss: 73.1783
# Epoch 36/50
#  - 0s - loss: 126.3694 - val_loss: 74.1983
# Epoch 37/50
#  - 0s - loss: 125.0545 - val_loss: 73.5521
# Epoch 38/50
#  - 0s - loss: 126.6531 - val_loss: 72.9317
# Epoch 39/50
#  - 0s - loss: 125.5936 - val_loss: 75.2929
# Epoch 40/50
#  - 0s - loss: 125.1735 - val_loss: 73.4543
# Epoch 41/50
#  - 0s - loss: 124.9537 - val_loss: 73.4594
# Epoch 42/50
#  - 0s - loss: 125.3188 - val_loss: 73.7606
# Epoch 43/50
#  - 0s - loss: 125.6537 - val_loss: 74.7126
# Epoch 44/50
#  - 0s - loss: 127.2142 - val_loss: 73.4504
# Epoch 45/50
#  - 0s - loss: 125.9105 - val_loss: 76.7395
# Epoch 46/50
#  - 0s - loss: 125.3595 - val_loss: 73.2563
# Epoch 47/50
#  - 0s - loss: 125.8119 - val_loss: 74.2400
# Epoch 48/50
#  - 0s - loss: 125.0989 - val_loss: 76.3918
# Epoch 49/50
#  - 0s - loss: 126.8019 - val_loss: 74.3094
# Epoch 50/50
#  - 0s - loss: 125.7447 - val_loss: 78.0624
#
# Number of time:  7
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 125.9302 - val_loss: 74.0517
# Epoch 2/50
#  - 0s - loss: 124.9422 - val_loss: 73.6221
# Epoch 3/50
#  - 0s - loss: 125.7176 - val_loss: 72.9683
# Epoch 4/50
#  - 0s - loss: 124.9967 - val_loss: 73.5249
# Epoch 5/50
#  - 0s - loss: 125.2280 - val_loss: 74.6334
# Epoch 6/50
#  - 0s - loss: 124.4100 - val_loss: 76.8582
# Epoch 7/50
#  - 0s - loss: 127.9286 - val_loss: 73.0826
# Epoch 8/50
#  - 0s - loss: 127.6179 - val_loss: 72.9565
# Epoch 9/50
#  - 0s - loss: 126.4165 - val_loss: 74.8700
# Epoch 10/50
#  - 0s - loss: 127.1048 - val_loss: 73.6155
# Epoch 11/50
#  - 0s - loss: 125.4106 - val_loss: 74.2233
# Epoch 12/50
#  - 0s - loss: 124.7821 - val_loss: 73.0759
# Epoch 13/50
#  - 0s - loss: 126.1285 - val_loss: 73.5199
# Epoch 14/50
#  - 0s - loss: 125.6556 - val_loss: 75.0566
# Epoch 15/50
#  - 0s - loss: 125.1589 - val_loss: 73.5306
# Epoch 16/50
#  - 0s - loss: 126.3677 - val_loss: 73.8726
# Epoch 17/50
#  - 0s - loss: 126.3034 - val_loss: 73.9533
# Epoch 18/50
#  - 0s - loss: 127.5921 - val_loss: 75.6040
# Epoch 19/50
#  - 0s - loss: 125.7223 - val_loss: 77.2439
# Epoch 20/50
#  - 0s - loss: 125.8845 - val_loss: 75.6355
# Epoch 21/50
#  - 0s - loss: 125.6352 - val_loss: 73.8512
# Epoch 22/50
#  - 0s - loss: 125.3924 - val_loss: 73.2816
# Epoch 23/50
#  - 0s - loss: 125.6151 - val_loss: 76.2729
# Epoch 24/50
#  - 0s - loss: 124.9999 - val_loss: 72.9974
# Epoch 25/50
#  - 0s - loss: 125.9205 - val_loss: 76.5613
# Epoch 26/50
#  - 0s - loss: 126.1398 - val_loss: 73.6243
# Epoch 27/50
#  - 0s - loss: 126.0749 - val_loss: 73.2847
# Epoch 28/50
#  - 0s - loss: 123.9851 - val_loss: 80.4365
# Epoch 29/50
#  - 0s - loss: 127.6991 - val_loss: 73.2704
# Epoch 30/50
#  - 0s - loss: 126.3916 - val_loss: 74.0320
# Epoch 31/50
#  - 0s - loss: 127.5037 - val_loss: 73.0454
# Epoch 32/50
#  - 0s - loss: 126.3536 - val_loss: 77.2933
# Epoch 33/50
#  - 0s - loss: 125.4885 - val_loss: 73.1076
# Epoch 34/50
#  - 0s - loss: 125.1755 - val_loss: 76.4546
# Epoch 35/50
#  - 0s - loss: 126.7652 - val_loss: 75.8562
# Epoch 36/50
#  - 0s - loss: 127.7928 - val_loss: 73.6369
# Epoch 37/50
#  - 0s - loss: 126.4723 - val_loss: 73.6229
# Epoch 38/50
#  - 0s - loss: 126.3901 - val_loss: 82.7493
# Epoch 39/50
#  - 0s - loss: 128.0463 - val_loss: 74.4191
# Epoch 40/50
#  - 0s - loss: 125.7479 - val_loss: 74.5949
# Epoch 41/50
#  - 0s - loss: 125.1343 - val_loss: 73.7441
# Epoch 42/50
#  - 0s - loss: 126.1692 - val_loss: 76.0927
# Epoch 43/50
#  - 0s - loss: 125.5993 - val_loss: 75.8231
# Epoch 44/50
#  - 0s - loss: 126.7369 - val_loss: 78.1701
# Epoch 45/50
#  - 0s - loss: 127.4218 - val_loss: 74.0266
# Epoch 46/50
#  - 0s - loss: 125.2385 - val_loss: 72.6914
# Epoch 47/50
#  - 0s - loss: 126.6297 - val_loss: 77.9664
# Epoch 48/50
#  - 0s - loss: 129.5083 - val_loss: 76.3337
# Epoch 49/50
#  - 0s - loss: 128.3226 - val_loss: 74.7217
# Epoch 50/50
#  - 0s - loss: 127.9067 - val_loss: 74.9231
#
# Number of time:  8
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 124.7419 - val_loss: 83.2120
# Epoch 2/50
#  - 0s - loss: 129.5857 - val_loss: 77.8949
# Epoch 3/50
#  - 0s - loss: 128.3998 - val_loss: 73.4347
# Epoch 4/50
#  - 0s - loss: 125.7678 - val_loss: 73.5312
# Epoch 5/50
#  - 0s - loss: 124.7576 - val_loss: 72.7878
# Epoch 6/50
#  - 0s - loss: 126.0807 - val_loss: 76.9306
# Epoch 7/50
#  - 0s - loss: 126.1688 - val_loss: 72.9680
# Epoch 8/50
#  - 0s - loss: 126.1816 - val_loss: 73.2627
# Epoch 9/50
#  - 0s - loss: 126.4697 - val_loss: 74.8542
# Epoch 10/50
#  - 0s - loss: 127.7366 - val_loss: 73.4084
# Epoch 11/50
#  - 0s - loss: 125.8200 - val_loss: 75.9051
# Epoch 12/50
#  - 0s - loss: 127.6494 - val_loss: 76.2950
# Epoch 13/50
#  - 0s - loss: 125.9058 - val_loss: 74.0367
# Epoch 14/50
#  - 0s - loss: 125.7734 - val_loss: 73.2302
# Epoch 15/50
#  - 0s - loss: 125.9981 - val_loss: 73.6189
# Epoch 16/50
#  - 0s - loss: 125.7793 - val_loss: 75.2573
# Epoch 17/50
#  - 0s - loss: 126.5753 - val_loss: 73.5711
# Epoch 18/50
#  - 0s - loss: 126.0645 - val_loss: 75.9856
# Epoch 19/50
#  - 0s - loss: 127.7445 - val_loss: 73.6882
# Epoch 20/50
#  - 0s - loss: 127.1729 - val_loss: 73.4784
# Epoch 21/50
#  - 0s - loss: 126.9319 - val_loss: 73.4736
# Epoch 22/50
#  - 0s - loss: 126.8611 - val_loss: 73.6679
# Epoch 23/50
#  - 0s - loss: 128.5008 - val_loss: 73.2887
# Epoch 24/50
#  - 0s - loss: 127.9999 - val_loss: 84.1520
# Epoch 25/50
#  - 0s - loss: 131.1290 - val_loss: 73.7954
# Epoch 26/50
#  - 0s - loss: 124.0737 - val_loss: 77.1599
# Epoch 27/50
#  - 0s - loss: 127.4032 - val_loss: 75.6053
# Epoch 28/50
#  - 0s - loss: 126.1782 - val_loss: 73.1572
# Epoch 29/50
#  - 0s - loss: 125.1756 - val_loss: 73.4895
# Epoch 30/50
#  - 0s - loss: 126.7712 - val_loss: 73.8418
# Epoch 31/50
#  - 0s - loss: 125.0978 - val_loss: 80.7209
# Epoch 32/50
#  - 0s - loss: 132.7686 - val_loss: 89.7765
# Epoch 33/50
#  - 0s - loss: 129.1630 - val_loss: 77.8499
# Epoch 34/50
#  - 0s - loss: 125.3091 - val_loss: 72.9448
# Epoch 35/50
#  - 0s - loss: 127.0810 - val_loss: 72.9481
# Epoch 36/50
#  - 0s - loss: 126.1258 - val_loss: 73.9843
# Epoch 37/50
#  - 0s - loss: 126.2073 - val_loss: 73.1598
# Epoch 38/50
#  - 0s - loss: 126.7657 - val_loss: 76.7187
# Epoch 39/50
#  - 0s - loss: 126.5748 - val_loss: 73.6852
# Epoch 40/50
#  - 0s - loss: 125.8659 - val_loss: 73.8256
# Epoch 41/50
#  - 0s - loss: 125.0911 - val_loss: 80.0985
# Epoch 42/50
#  - 0s - loss: 130.0813 - val_loss: 79.5979
# Epoch 43/50
#  - 0s - loss: 126.2303 - val_loss: 73.8278
# Epoch 44/50
#  - 0s - loss: 126.9620 - val_loss: 75.8682
# Epoch 45/50
#  - 0s - loss: 126.5205 - val_loss: 75.6725
# Epoch 46/50
#  - 0s - loss: 130.0955 - val_loss: 76.5160
# Epoch 47/50
#  - 0s - loss: 124.9495 - val_loss: 86.4433
# Epoch 48/50
#  - 0s - loss: 126.9979 - val_loss: 81.4602
# Epoch 49/50
#  - 0s - loss: 127.2436 - val_loss: 73.6455
# Epoch 50/50
#  - 0s - loss: 125.1217 - val_loss: 74.9135
#
# Number of time:  9
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 127.3443 - val_loss: 76.3921
# Epoch 2/50
#  - 0s - loss: 126.7238 - val_loss: 77.1609
# Epoch 3/50
#  - 0s - loss: 125.2344 - val_loss: 73.7927
# Epoch 4/50
#  - 0s - loss: 125.1946 - val_loss: 77.7763
# Epoch 5/50
#  - 0s - loss: 126.7324 - val_loss: 73.6174
# Epoch 6/50
#  - 0s - loss: 127.6328 - val_loss: 83.4471
# Epoch 7/50
#  - 0s - loss: 126.6065 - val_loss: 73.6062
# Epoch 8/50
#  - 0s - loss: 125.5068 - val_loss: 73.7805
# Epoch 9/50
#  - 0s - loss: 125.3163 - val_loss: 72.9819
# Epoch 10/50
#  - 0s - loss: 131.1921 - val_loss: 74.3333
# Epoch 11/50
#  - 0s - loss: 127.0130 - val_loss: 72.9516
# Epoch 12/50
#  - 0s - loss: 124.6313 - val_loss: 79.2013
# Epoch 13/50
#  - 0s - loss: 127.7151 - val_loss: 73.6118
# Epoch 14/50
#  - 0s - loss: 125.1124 - val_loss: 82.3006
# Epoch 15/50
#  - 0s - loss: 125.1234 - val_loss: 73.2786
# Epoch 16/50
#  - 0s - loss: 127.3471 - val_loss: 73.0636
# Epoch 17/50
#  - 0s - loss: 125.7965 - val_loss: 74.8874
# Epoch 18/50
#  - 0s - loss: 125.2786 - val_loss: 73.6435
# Epoch 19/50
#  - 0s - loss: 125.2877 - val_loss: 73.2473
# Epoch 20/50
#  - 0s - loss: 125.2697 - val_loss: 73.2969
# Epoch 21/50
#  - 0s - loss: 124.8448 - val_loss: 77.7765
# Epoch 22/50
#  - 0s - loss: 125.5066 - val_loss: 72.9024
# Epoch 23/50
#  - 0s - loss: 125.5734 - val_loss: 74.0313
# Epoch 24/50
#  - 0s - loss: 127.8475 - val_loss: 76.0387
# Epoch 25/50
#  - 0s - loss: 124.8390 - val_loss: 75.3552
# Epoch 26/50
#  - 0s - loss: 125.3344 - val_loss: 76.0403
# Epoch 27/50
#  - 0s - loss: 126.1782 - val_loss: 73.1942
# Epoch 28/50
#  - 0s - loss: 125.9361 - val_loss: 78.5704
# Epoch 29/50
#  - 0s - loss: 125.5909 - val_loss: 73.5460
# Epoch 30/50
#  - 0s - loss: 126.4982 - val_loss: 73.0101
# Epoch 31/50
#  - 0s - loss: 126.6206 - val_loss: 77.0689
# Epoch 32/50
#  - 0s - loss: 126.6811 - val_loss: 73.1563
# Epoch 33/50
#  - 0s - loss: 125.7225 - val_loss: 73.2730
# Epoch 34/50
#  - 0s - loss: 125.1820 - val_loss: 74.5262
# Epoch 35/50
#  - 0s - loss: 127.8045 - val_loss: 73.5225
# Epoch 36/50
#  - 0s - loss: 127.7297 - val_loss: 74.9759
# Epoch 37/50
#  - 0s - loss: 126.7171 - val_loss: 72.7637
# Epoch 38/50
#  - 0s - loss: 125.2188 - val_loss: 75.1812
# Epoch 39/50
#  - 0s - loss: 128.0358 - val_loss: 72.6745
# Epoch 40/50
#  - 0s - loss: 124.9189 - val_loss: 75.9682
# Epoch 41/50
#  - 0s - loss: 126.2553 - val_loss: 73.1454
# Epoch 42/50
#  - 0s - loss: 131.5709 - val_loss: 73.2928
# Epoch 43/50
#  - 0s - loss: 128.4052 - val_loss: 75.1185
# Epoch 44/50
#  - 0s - loss: 127.2231 - val_loss: 76.1767
# Epoch 45/50
#  - 0s - loss: 126.7988 - val_loss: 76.0068
# Epoch 46/50
#  - 0s - loss: 125.9466 - val_loss: 72.9234
# Epoch 47/50
#  - 0s - loss: 126.5650 - val_loss: 80.2924
# Epoch 48/50
#  - 0s - loss: 128.7654 - val_loss: 73.6145
# Epoch 49/50
#  - 0s - loss: 125.2727 - val_loss: 74.8730
# Epoch 50/50
#  - 0s - loss: 125.9427 - val_loss: 73.6445
#
# Number of time:  10
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 125.4574 - val_loss: 73.3221
# Epoch 2/50
#  - 0s - loss: 125.8116 - val_loss: 74.3831
# Epoch 3/50
#  - 0s - loss: 125.5197 - val_loss: 73.2116
# Epoch 4/50
#  - 0s - loss: 126.3464 - val_loss: 76.7225
# Epoch 5/50
#  - 0s - loss: 125.8525 - val_loss: 73.1375
# Epoch 6/50
#  - 0s - loss: 126.1978 - val_loss: 72.7328
# Epoch 7/50
#  - 0s - loss: 126.7133 - val_loss: 74.7010
# Epoch 8/50
#  - 0s - loss: 127.4357 - val_loss: 73.3954
# Epoch 9/50
#  - 0s - loss: 126.8072 - val_loss: 73.1628
# Epoch 10/50
#  - 0s - loss: 127.8094 - val_loss: 73.5373
# Epoch 11/50
#  - 0s - loss: 125.6912 - val_loss: 75.5665
# Epoch 12/50
#  - 0s - loss: 125.5304 - val_loss: 73.0573
# Epoch 13/50
#  - 0s - loss: 126.2712 - val_loss: 73.5260
# Epoch 14/50
#  - 0s - loss: 125.6004 - val_loss: 73.1428
# Epoch 15/50
#  - 0s - loss: 125.5877 - val_loss: 73.9804
# Epoch 16/50
#  - 0s - loss: 125.4899 - val_loss: 75.0240
# Epoch 17/50
#  - 0s - loss: 125.5223 - val_loss: 76.9856
# Epoch 18/50
#  - 0s - loss: 126.1463 - val_loss: 73.9785
# Epoch 19/50
#  - 0s - loss: 124.9395 - val_loss: 73.3591
# Epoch 20/50
#  - 0s - loss: 125.5005 - val_loss: 73.6366
# Epoch 21/50
#  - 0s - loss: 127.4437 - val_loss: 73.5184
# Epoch 22/50
#  - 0s - loss: 125.9935 - val_loss: 73.4138
# Epoch 23/50
#  - 0s - loss: 126.3347 - val_loss: 72.9948
# Epoch 24/50
#  - 0s - loss: 126.2153 - val_loss: 73.2973
# Epoch 25/50
#  - 0s - loss: 127.6550 - val_loss: 74.2345
# Epoch 26/50
#  - 0s - loss: 125.1632 - val_loss: 76.1302
# Epoch 27/50
#  - 0s - loss: 128.0688 - val_loss: 85.8067
# Epoch 28/50
#  - 0s - loss: 128.6327 - val_loss: 73.1920
# Epoch 29/50
#  - 0s - loss: 126.6268 - val_loss: 73.1063
# Epoch 30/50
#  - 0s - loss: 126.9708 - val_loss: 72.9597
# Epoch 31/50
#  - 0s - loss: 126.1177 - val_loss: 73.1718
# Epoch 32/50
#  - 0s - loss: 126.0100 - val_loss: 73.4341
# Epoch 33/50
#  - 0s - loss: 126.3746 - val_loss: 73.7689
# Epoch 34/50
#  - 0s - loss: 126.5169 - val_loss: 74.8429
# Epoch 35/50
#  - 0s - loss: 124.9769 - val_loss: 74.1376
# Epoch 36/50
#  - 0s - loss: 128.3889 - val_loss: 74.7198
# Epoch 37/50
#  - 0s - loss: 126.4699 - val_loss: 73.0528
# Epoch 38/50
#  - 0s - loss: 125.0601 - val_loss: 73.0835
# Epoch 39/50
#  - 0s - loss: 126.0122 - val_loss: 79.1243
# Epoch 40/50
#  - 0s - loss: 127.6521 - val_loss: 73.2933
# Epoch 41/50
#  - 0s - loss: 125.0584 - val_loss: 72.9669
# Epoch 42/50
#  - 0s - loss: 125.5277 - val_loss: 75.0767
# Epoch 43/50
#  - 0s - loss: 127.8367 - val_loss: 73.3453
# Epoch 44/50
#  - 0s - loss: 125.4981 - val_loss: 75.2498
# Epoch 45/50
#  - 0s - loss: 127.4082 - val_loss: 76.0615
# Epoch 46/50
#  - 0s - loss: 125.3512 - val_loss: 73.3979
# Epoch 47/50
#  - 0s - loss: 125.1214 - val_loss: 73.6496
# Epoch 48/50
#  - 0s - loss: 126.2873 - val_loss: 75.6008
# Epoch 49/50
#  - 0s - loss: 125.4643 - val_loss: 73.1177
# Epoch 50/50
#  - 0s - loss: 127.7921 - val_loss: 72.7808
#
# Number of time:  11
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 125.4191 - val_loss: 73.0199
# Epoch 2/50
#  - 0s - loss: 125.1612 - val_loss: 73.4719
# Epoch 3/50
#  - 0s - loss: 126.2192 - val_loss: 73.6296
# Epoch 4/50
#  - 0s - loss: 125.5316 - val_loss: 73.7762
# Epoch 5/50
#  - 0s - loss: 125.2720 - val_loss: 74.9319
# Epoch 6/50
#  - 0s - loss: 126.9454 - val_loss: 73.8892
# Epoch 7/50
#  - 0s - loss: 124.7341 - val_loss: 73.7248
# Epoch 8/50
#  - 0s - loss: 128.4075 - val_loss: 73.7752
# Epoch 9/50
#  - 0s - loss: 127.5771 - val_loss: 73.8780
# Epoch 10/50
#  - 0s - loss: 124.7534 - val_loss: 73.2741
# Epoch 11/50
#  - 0s - loss: 125.9532 - val_loss: 73.6955
# Epoch 12/50
#  - 0s - loss: 128.2224 - val_loss: 73.9500
# Epoch 13/50
#  - 0s - loss: 131.3167 - val_loss: 77.0385
# Epoch 14/50
#  - 0s - loss: 125.1403 - val_loss: 72.8667
# Epoch 15/50
#  - 0s - loss: 124.4942 - val_loss: 74.0698
# Epoch 16/50
#  - 0s - loss: 126.3852 - val_loss: 73.4374
# Epoch 17/50
#  - 0s - loss: 125.3408 - val_loss: 72.7801
# Epoch 18/50
#  - 0s - loss: 126.6866 - val_loss: 72.5964
# Epoch 19/50
#  - 0s - loss: 125.3726 - val_loss: 74.1114
# Epoch 20/50
#  - 0s - loss: 126.5550 - val_loss: 73.2152
# Epoch 21/50
#  - 0s - loss: 128.0739 - val_loss: 73.5906
# Epoch 22/50
#  - 0s - loss: 125.3364 - val_loss: 73.8486
# Epoch 23/50
#  - 0s - loss: 125.0160 - val_loss: 73.9119
# Epoch 24/50
#  - 0s - loss: 124.9609 - val_loss: 76.0085
# Epoch 25/50
#  - 0s - loss: 126.1366 - val_loss: 73.2285
# Epoch 26/50
#  - 0s - loss: 125.3744 - val_loss: 73.6513
# Epoch 27/50
#  - 0s - loss: 125.0280 - val_loss: 73.2821
# Epoch 28/50
#  - 0s - loss: 125.1965 - val_loss: 72.7210
# Epoch 29/50
#  - 0s - loss: 126.5529 - val_loss: 73.5867
# Epoch 30/50
#  - 0s - loss: 125.4049 - val_loss: 73.4426
# Epoch 31/50
#  - 0s - loss: 125.0340 - val_loss: 73.4960
# Epoch 32/50
#  - 0s - loss: 125.6128 - val_loss: 74.2556
# Epoch 33/50
#  - 0s - loss: 126.9182 - val_loss: 73.3550
# Epoch 34/50
#  - 0s - loss: 126.2839 - val_loss: 73.9776
# Epoch 35/50
#  - 0s - loss: 125.5424 - val_loss: 73.2610
# Epoch 36/50
#  - 0s - loss: 125.4319 - val_loss: 73.0304
# Epoch 37/50
#  - 0s - loss: 125.9741 - val_loss: 78.6304
# Epoch 38/50
#  - 0s - loss: 124.9671 - val_loss: 73.1358
# Epoch 39/50
#  - 0s - loss: 126.7292 - val_loss: 73.5658
# Epoch 40/50
#  - 0s - loss: 126.7111 - val_loss: 73.4862
# Epoch 41/50
#  - 0s - loss: 124.9401 - val_loss: 74.1327
# Epoch 42/50
#  - 0s - loss: 125.1823 - val_loss: 73.6238
# Epoch 43/50
#  - 0s - loss: 127.0434 - val_loss: 73.6910
# Epoch 44/50
#  - 0s - loss: 126.2159 - val_loss: 83.8659
# Epoch 45/50
#  - 0s - loss: 128.1932 - val_loss: 73.7167
# Epoch 46/50
#  - 0s - loss: 125.0572 - val_loss: 73.0981
# Epoch 47/50
#  - 0s - loss: 126.1527 - val_loss: 74.4335
# Epoch 48/50
#  - 0s - loss: 126.8990 - val_loss: 78.3947
# Epoch 49/50
#  - 0s - loss: 131.9506 - val_loss: 74.5769
# Epoch 50/50
#  - 0s - loss: 134.6133 - val_loss: 78.7758
#
# Number of time:  12
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 128.4925 - val_loss: 73.2169
# Epoch 2/50
#  - 0s - loss: 125.0735 - val_loss: 73.5619
# Epoch 3/50
#  - 0s - loss: 124.8700 - val_loss: 73.6858
# Epoch 4/50
#  - 0s - loss: 126.7479 - val_loss: 74.4486
# Epoch 5/50
#  - 0s - loss: 127.4013 - val_loss: 74.9273
# Epoch 6/50
#  - 0s - loss: 125.6093 - val_loss: 74.5311
# Epoch 7/50
#  - 0s - loss: 127.4525 - val_loss: 72.6916
# Epoch 8/50
#  - 0s - loss: 125.8234 - val_loss: 74.2105
# Epoch 9/50
#  - 0s - loss: 127.1717 - val_loss: 79.0059
# Epoch 10/50
#  - 0s - loss: 129.0275 - val_loss: 73.2794
# Epoch 11/50
#  - 0s - loss: 126.3138 - val_loss: 74.1167
# Epoch 12/50
#  - 0s - loss: 125.1846 - val_loss: 74.1125
# Epoch 13/50
#  - 0s - loss: 128.9557 - val_loss: 75.1775
# Epoch 14/50
#  - 0s - loss: 127.1770 - val_loss: 74.8688
# Epoch 15/50
#  - 0s - loss: 126.6598 - val_loss: 72.8291
# Epoch 16/50
#  - 0s - loss: 126.5351 - val_loss: 72.5581
# Epoch 17/50
#  - 0s - loss: 125.7105 - val_loss: 73.8113
# Epoch 18/50
#  - 0s - loss: 126.1391 - val_loss: 74.1195
# Epoch 19/50
#  - 0s - loss: 125.5030 - val_loss: 73.6001
# Epoch 20/50
#  - 0s - loss: 125.1235 - val_loss: 73.9627
# Epoch 21/50
#  - 0s - loss: 127.3873 - val_loss: 76.1636
# Epoch 22/50
#  - 0s - loss: 125.4017 - val_loss: 74.5104
# Epoch 23/50
#  - 0s - loss: 124.9072 - val_loss: 73.5032
# Epoch 24/50
#  - 0s - loss: 125.0157 - val_loss: 73.3375
# Epoch 25/50
#  - 0s - loss: 125.9618 - val_loss: 76.1036
# Epoch 26/50
#  - 0s - loss: 127.1873 - val_loss: 74.5804
# Epoch 27/50
#  - 0s - loss: 125.0867 - val_loss: 78.1118
# Epoch 28/50
#  - 0s - loss: 126.4605 - val_loss: 75.4283
# Epoch 29/50
#  - 0s - loss: 128.9743 - val_loss: 77.0381
# Epoch 30/50
#  - 0s - loss: 128.3488 - val_loss: 74.7344
# Epoch 31/50
#  - 0s - loss: 125.1379 - val_loss: 73.0464
# Epoch 32/50
#  - 0s - loss: 124.7847 - val_loss: 73.4058
# Epoch 33/50
#  - 0s - loss: 126.1282 - val_loss: 72.8164
# Epoch 34/50
#  - 0s - loss: 125.9799 - val_loss: 73.5392
# Epoch 35/50
#  - 0s - loss: 125.8164 - val_loss: 73.8915
# Epoch 36/50
#  - 0s - loss: 125.4765 - val_loss: 73.7309
# Epoch 37/50
#  - 0s - loss: 125.3038 - val_loss: 73.5767
# Epoch 38/50
#  - 0s - loss: 125.8215 - val_loss: 72.9710
# Epoch 39/50
#  - 0s - loss: 126.5811 - val_loss: 74.5516
# Epoch 40/50
#  - 0s - loss: 125.0596 - val_loss: 74.2504
# Epoch 41/50
#  - 0s - loss: 125.5220 - val_loss: 73.5698
# Epoch 42/50
#  - 0s - loss: 125.3840 - val_loss: 73.8345
# Epoch 43/50
#  - 0s - loss: 125.2508 - val_loss: 73.3279
# Epoch 44/50
#  - 0s - loss: 126.1160 - val_loss: 75.3022
# Epoch 45/50
#  - 0s - loss: 126.4104 - val_loss: 73.3854
# Epoch 46/50
#  - 0s - loss: 127.9443 - val_loss: 73.6554
# Epoch 47/50
#  - 0s - loss: 125.4843 - val_loss: 72.5771
# Epoch 48/50
#  - 0s - loss: 125.3813 - val_loss: 76.7405
# Epoch 49/50
#  - 0s - loss: 125.8169 - val_loss: 73.4347
# Epoch 50/50
#  - 0s - loss: 125.2156 - val_loss: 73.3408
#
# Number of time:  13
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 124.9105 - val_loss: 73.1098
# Epoch 2/50
#  - 0s - loss: 124.9616 - val_loss: 73.0509
# Epoch 3/50
#  - 0s - loss: 127.8281 - val_loss: 74.7213
# Epoch 4/50
#  - 0s - loss: 127.4787 - val_loss: 73.3483
# Epoch 5/50
#  - 0s - loss: 128.4830 - val_loss: 73.8216
# Epoch 6/50
#  - 0s - loss: 125.2729 - val_loss: 73.3356
# Epoch 7/50
#  - 0s - loss: 125.6665 - val_loss: 73.1587
# Epoch 8/50
#  - 0s - loss: 129.7985 - val_loss: 85.2922
# Epoch 9/50
#  - 0s - loss: 129.8314 - val_loss: 73.5231
# Epoch 10/50
#  - 0s - loss: 126.8578 - val_loss: 73.3700
# Epoch 11/50
#  - 0s - loss: 129.9733 - val_loss: 73.8792
# Epoch 12/50
#  - 0s - loss: 125.1217 - val_loss: 72.8254
# Epoch 13/50
#  - 0s - loss: 124.9401 - val_loss: 74.0196
# Epoch 14/50
#  - 0s - loss: 126.5489 - val_loss: 73.1645
# Epoch 15/50
#  - 0s - loss: 125.2073 - val_loss: 73.3319
# Epoch 16/50
#  - 0s - loss: 125.3291 - val_loss: 72.8048
# Epoch 17/50
#  - 0s - loss: 125.8655 - val_loss: 74.5025
# Epoch 18/50
#  - 0s - loss: 129.2645 - val_loss: 74.0750
# Epoch 19/50
#  - 0s - loss: 127.6114 - val_loss: 74.6119
# Epoch 20/50
#  - 0s - loss: 126.3497 - val_loss: 81.0918
# Epoch 21/50
#  - 0s - loss: 127.9904 - val_loss: 82.1444
# Epoch 22/50
#  - 0s - loss: 126.6186 - val_loss: 79.9253
# Epoch 23/50
#  - 0s - loss: 125.5546 - val_loss: 74.2163
# Epoch 24/50
#  - 0s - loss: 125.1990 - val_loss: 73.6108
# Epoch 25/50
#  - 0s - loss: 126.0692 - val_loss: 74.8155
# Epoch 26/50
#  - 0s - loss: 125.0659 - val_loss: 73.4631
# Epoch 27/50
#  - 0s - loss: 125.7821 - val_loss: 73.3339
# Epoch 28/50
#  - 0s - loss: 125.4114 - val_loss: 73.1778
# Epoch 29/50
#  - 0s - loss: 127.8695 - val_loss: 73.8142
# Epoch 30/50
#  - 0s - loss: 128.3872 - val_loss: 73.3160
# Epoch 31/50
#  - 0s - loss: 126.1367 - val_loss: 74.9944
# Epoch 32/50
#  - 0s - loss: 126.1808 - val_loss: 73.2276
# Epoch 33/50
#  - 0s - loss: 124.9711 - val_loss: 75.8351
# Epoch 34/50
#  - 0s - loss: 127.5317 - val_loss: 72.9145
# Epoch 35/50
#  - 0s - loss: 125.2193 - val_loss: 75.1696
# Epoch 36/50
#  - 0s - loss: 125.5304 - val_loss: 72.8928
# Epoch 37/50
#  - 0s - loss: 125.0219 - val_loss: 76.6726
# Epoch 38/50
#  - 0s - loss: 125.3814 - val_loss: 72.9260
# Epoch 39/50
#  - 0s - loss: 125.8277 - val_loss: 73.8730
# Epoch 40/50
#  - 0s - loss: 125.3439 - val_loss: 77.6225
# Epoch 41/50
#  - 0s - loss: 129.0647 - val_loss: 80.2033
# Epoch 42/50
#  - 0s - loss: 125.9320 - val_loss: 74.3550
# Epoch 43/50
#  - 0s - loss: 125.7924 - val_loss: 75.0163
# Epoch 44/50
#  - 0s - loss: 125.6152 - val_loss: 76.8157
# Epoch 45/50
#  - 0s - loss: 124.9391 - val_loss: 76.0910
# Epoch 46/50
#  - 0s - loss: 126.2970 - val_loss: 75.0865
# Epoch 47/50
#  - 0s - loss: 125.6974 - val_loss: 74.9930
# Epoch 48/50
#  - 0s - loss: 125.6501 - val_loss: 74.1544
# Epoch 49/50
#  - 0s - loss: 126.7272 - val_loss: 73.6371
# Epoch 50/50
#  - 0s - loss: 125.4762 - val_loss: 75.1233
#
# Number of time:  14
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 126.0259 - val_loss: 75.9722
# Epoch 2/50
#  - 0s - loss: 127.4642 - val_loss: 75.9650
# Epoch 3/50
#  - 0s - loss: 128.8295 - val_loss: 86.9584
# Epoch 4/50
#  - 0s - loss: 127.0229 - val_loss: 73.5754
# Epoch 5/50
#  - 0s - loss: 127.6385 - val_loss: 75.1317
# Epoch 6/50
#  - 0s - loss: 125.3711 - val_loss: 73.6423
# Epoch 7/50
#  - 0s - loss: 125.0845 - val_loss: 73.7241
# Epoch 8/50
#  - 0s - loss: 125.9865 - val_loss: 73.6170
# Epoch 9/50
#  - 0s - loss: 125.2653 - val_loss: 74.8677
# Epoch 10/50
#  - 0s - loss: 125.5474 - val_loss: 73.8957
# Epoch 11/50
#  - 0s - loss: 124.5908 - val_loss: 73.4722
# Epoch 12/50
#  - 0s - loss: 125.8171 - val_loss: 73.0420
# Epoch 13/50
#  - 0s - loss: 125.4316 - val_loss: 72.8493
# Epoch 14/50
#  - 0s - loss: 125.1534 - val_loss: 75.4660
# Epoch 15/50
#  - 0s - loss: 124.8476 - val_loss: 74.0771
# Epoch 16/50
#  - 0s - loss: 125.8782 - val_loss: 74.8728
# Epoch 17/50
#  - 0s - loss: 126.4921 - val_loss: 73.0265
# Epoch 18/50
#  - 0s - loss: 125.9749 - val_loss: 72.8945
# Epoch 19/50
#  - 0s - loss: 125.5289 - val_loss: 73.8133
# Epoch 20/50
#  - 0s - loss: 125.6759 - val_loss: 74.1148
# Epoch 21/50
#  - 0s - loss: 124.9886 - val_loss: 73.3605
# Epoch 22/50
#  - 0s - loss: 124.7370 - val_loss: 75.5469
# Epoch 23/50
#  - 0s - loss: 125.7860 - val_loss: 73.4135
# Epoch 24/50
#  - 0s - loss: 125.0732 - val_loss: 74.7539
# Epoch 25/50
#  - 0s - loss: 128.2323 - val_loss: 74.0686
# Epoch 26/50
#  - 0s - loss: 126.1132 - val_loss: 73.4163
# Epoch 27/50
#  - 0s - loss: 125.5599 - val_loss: 73.5823
# Epoch 28/50
#  - 0s - loss: 125.9446 - val_loss: 73.8316
# Epoch 29/50
#  - 0s - loss: 128.4293 - val_loss: 74.6076
# Epoch 30/50
#  - 0s - loss: 126.3979 - val_loss: 75.3147
# Epoch 31/50
#  - 0s - loss: 126.4366 - val_loss: 73.0574
# Epoch 32/50
#  - 0s - loss: 125.7742 - val_loss: 73.3274
# Epoch 33/50
#  - 0s - loss: 126.2419 - val_loss: 74.1448
# Epoch 34/50
#  - 0s - loss: 125.6539 - val_loss: 79.4966
# Epoch 35/50
#  - 0s - loss: 125.6352 - val_loss: 73.0209
# Epoch 36/50
#  - 0s - loss: 124.9068 - val_loss: 73.5932
# Epoch 37/50
#  - 0s - loss: 126.6470 - val_loss: 85.1770
# Epoch 38/50
#  - 0s - loss: 129.3457 - val_loss: 74.7416
# Epoch 39/50
#  - 0s - loss: 126.2222 - val_loss: 73.0831
# Epoch 40/50
#  - 0s - loss: 125.1974 - val_loss: 74.6228
# Epoch 41/50
#  - 0s - loss: 126.8541 - val_loss: 73.8252
# Epoch 42/50
#  - 0s - loss: 125.1507 - val_loss: 73.8017
# Epoch 43/50
#  - 0s - loss: 129.5202 - val_loss: 74.2741
# Epoch 44/50
#  - 0s - loss: 126.4475 - val_loss: 74.8672
# Epoch 45/50
#  - 0s - loss: 126.2700 - val_loss: 73.8869
# Epoch 46/50
#  - 0s - loss: 125.4830 - val_loss: 73.0491
# Epoch 47/50
#  - 0s - loss: 126.3579 - val_loss: 73.8584
# Epoch 48/50
#  - 0s - loss: 124.8478 - val_loss: 73.1166
# Epoch 49/50
#  - 0s - loss: 127.7553 - val_loss: 77.6565
# Epoch 50/50
#  - 0s - loss: 126.3716 - val_loss: 73.9911
#
# Number of time:  15
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 127.7328 - val_loss: 80.3530
# Epoch 2/50
#  - 0s - loss: 125.4751 - val_loss: 73.5793
# Epoch 3/50
#  - 0s - loss: 125.2563 - val_loss: 73.4018
# Epoch 4/50
#  - 0s - loss: 126.5146 - val_loss: 73.2289
# Epoch 5/50
#  - 0s - loss: 125.5630 - val_loss: 73.5480
# Epoch 6/50
#  - 0s - loss: 125.1223 - val_loss: 74.3237
# Epoch 7/50
#  - 0s - loss: 127.1897 - val_loss: 74.9642
# Epoch 8/50
#  - 0s - loss: 125.4747 - val_loss: 78.9840
# Epoch 9/50
#  - 0s - loss: 126.3301 - val_loss: 76.6458
# Epoch 10/50
#  - 0s - loss: 125.9916 - val_loss: 72.6555
# Epoch 11/50
#  - 0s - loss: 125.5305 - val_loss: 74.0155
# Epoch 12/50
#  - 0s - loss: 126.5852 - val_loss: 72.6115
# Epoch 13/50
#  - 0s - loss: 129.1474 - val_loss: 75.8773
# Epoch 14/50
#  - 0s - loss: 128.4446 - val_loss: 73.6163
# Epoch 15/50
#  - 0s - loss: 125.8469 - val_loss: 72.5788
# Epoch 16/50
#  - 0s - loss: 128.9124 - val_loss: 73.2611
# Epoch 17/50
#  - 0s - loss: 128.1876 - val_loss: 79.5298
# Epoch 18/50
#  - 0s - loss: 129.3063 - val_loss: 74.0191
# Epoch 19/50
#  - 0s - loss: 124.7307 - val_loss: 79.1662
# Epoch 20/50
#  - 0s - loss: 125.5282 - val_loss: 74.7103
# Epoch 21/50
#  - 0s - loss: 125.5054 - val_loss: 73.2731
# Epoch 22/50
#  - 0s - loss: 124.9616 - val_loss: 73.1764
# Epoch 23/50
#  - 0s - loss: 125.4227 - val_loss: 73.6495
# Epoch 24/50
#  - 0s - loss: 127.3531 - val_loss: 72.7753
# Epoch 25/50
#  - 0s - loss: 125.0863 - val_loss: 73.5511
# Epoch 26/50
#  - 0s - loss: 125.1767 - val_loss: 75.1389
# Epoch 27/50
#  - 0s - loss: 125.2882 - val_loss: 72.8401
# Epoch 28/50
#  - 0s - loss: 126.0970 - val_loss: 73.9279
# Epoch 29/50
#  - 0s - loss: 126.2066 - val_loss: 73.0069
# Epoch 30/50
#  - 0s - loss: 126.5319 - val_loss: 73.4732
# Epoch 31/50
#  - 0s - loss: 125.4795 - val_loss: 72.8132
# Epoch 32/50
#  - 0s - loss: 125.2599 - val_loss: 73.3431
# Epoch 33/50
#  - 0s - loss: 125.4498 - val_loss: 73.9989
# Epoch 34/50
#  - 0s - loss: 126.0699 - val_loss: 74.8354
# Epoch 35/50
#  - 0s - loss: 126.3293 - val_loss: 73.4075
# Epoch 36/50
#  - 0s - loss: 125.6545 - val_loss: 73.0343
# Epoch 37/50
#  - 0s - loss: 125.1718 - val_loss: 78.4318
# Epoch 38/50
#  - 0s - loss: 125.4809 - val_loss: 76.8129
# Epoch 39/50
#  - 0s - loss: 127.0980 - val_loss: 77.4981
# Epoch 40/50
#  - 0s - loss: 125.2476 - val_loss: 76.5266
# Epoch 41/50
#  - 0s - loss: 126.8688 - val_loss: 76.1729
# Epoch 42/50
#  - 0s - loss: 125.0473 - val_loss: 73.9690
# Epoch 43/50
#  - 0s - loss: 125.1688 - val_loss: 73.9958
# Epoch 44/50
#  - 0s - loss: 125.2539 - val_loss: 74.1422
# Epoch 45/50
#  - 0s - loss: 125.6477 - val_loss: 73.3127
# Epoch 46/50
#  - 0s - loss: 128.2805 - val_loss: 82.2164
# Epoch 47/50
#  - 0s - loss: 129.5686 - val_loss: 74.7611
# Epoch 48/50
#  - 0s - loss: 125.0344 - val_loss: 74.2256
# Epoch 49/50
#  - 0s - loss: 124.9268 - val_loss: 74.5445
# Epoch 50/50
#  - 0s - loss: 128.8362 - val_loss: 75.2803
#
# Number of time:  16
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 127.5883 - val_loss: 77.4314
# Epoch 2/50
#  - 0s - loss: 127.6346 - val_loss: 72.7088
# Epoch 3/50
#  - 0s - loss: 124.8616 - val_loss: 72.8342
# Epoch 4/50
#  - 0s - loss: 126.9198 - val_loss: 73.3399
# Epoch 5/50
#  - 0s - loss: 126.6641 - val_loss: 73.1422
# Epoch 6/50
#  - 0s - loss: 125.3860 - val_loss: 74.6427
# Epoch 7/50
#  - 0s - loss: 127.0755 - val_loss: 80.6458
# Epoch 8/50
#  - 0s - loss: 126.2977 - val_loss: 73.3418
# Epoch 9/50
#  - 0s - loss: 125.5733 - val_loss: 74.4462
# Epoch 10/50
#  - 0s - loss: 127.2628 - val_loss: 73.7534
# Epoch 11/50
#  - 0s - loss: 127.2705 - val_loss: 76.3102
# Epoch 12/50
#  - 0s - loss: 126.9970 - val_loss: 82.7543
# Epoch 13/50
#  - 0s - loss: 130.9772 - val_loss: 73.8194
# Epoch 14/50
#  - 0s - loss: 125.5985 - val_loss: 82.8249
# Epoch 15/50
#  - 0s - loss: 127.6342 - val_loss: 76.6280
# Epoch 16/50
#  - 0s - loss: 128.7624 - val_loss: 75.6486
# Epoch 17/50
#  - 0s - loss: 127.1530 - val_loss: 75.6451
# Epoch 18/50
#  - 0s - loss: 126.4958 - val_loss: 80.9674
# Epoch 19/50
#  - 0s - loss: 125.6703 - val_loss: 73.2228
# Epoch 20/50
#  - 0s - loss: 124.8905 - val_loss: 79.2318
# Epoch 21/50
#  - 0s - loss: 126.7363 - val_loss: 73.0511
# Epoch 22/50
#  - 0s - loss: 128.6134 - val_loss: 73.5359
# Epoch 23/50
#  - 0s - loss: 127.1538 - val_loss: 85.1905
# Epoch 24/50
#  - 0s - loss: 130.6708 - val_loss: 75.0195
# Epoch 25/50
#  - 0s - loss: 126.1626 - val_loss: 74.9365
# Epoch 26/50
#  - 0s - loss: 124.8238 - val_loss: 74.1875
# Epoch 27/50
#  - 0s - loss: 125.1492 - val_loss: 73.5594
# Epoch 28/50
#  - 0s - loss: 125.9372 - val_loss: 73.6074
# Epoch 29/50
#  - 0s - loss: 127.3148 - val_loss: 73.3922
# Epoch 30/50
#  - 0s - loss: 127.8067 - val_loss: 73.5625
# Epoch 31/50
#  - 0s - loss: 127.0583 - val_loss: 79.3671
# Epoch 32/50
#  - 0s - loss: 129.4747 - val_loss: 78.8512
# Epoch 33/50
#  - 0s - loss: 128.6221 - val_loss: 78.6138
# Epoch 34/50
#  - 0s - loss: 125.1234 - val_loss: 73.7017
# Epoch 35/50
#  - 0s - loss: 125.4572 - val_loss: 73.6855
# Epoch 36/50
#  - 0s - loss: 125.2890 - val_loss: 75.7352
# Epoch 37/50
#  - 0s - loss: 126.5166 - val_loss: 72.6892
# Epoch 38/50
#  - 0s - loss: 126.4202 - val_loss: 73.1813
# Epoch 39/50
#  - 0s - loss: 126.6806 - val_loss: 74.1383
# Epoch 40/50
#  - 0s - loss: 125.4705 - val_loss: 73.6596
# Epoch 41/50
#  - 0s - loss: 125.7073 - val_loss: 73.1597
# Epoch 42/50
#  - 0s - loss: 127.3982 - val_loss: 73.7279
# Epoch 43/50
#  - 0s - loss: 131.0968 - val_loss: 77.4060
# Epoch 44/50
#  - 0s - loss: 127.7528 - val_loss: 73.5242
# Epoch 45/50
#  - 0s - loss: 126.1808 - val_loss: 75.3768
# Epoch 46/50
#  - 0s - loss: 125.6903 - val_loss: 73.8469
# Epoch 47/50
#  - 0s - loss: 126.9069 - val_loss: 72.9665
# Epoch 48/50
#  - 0s - loss: 125.2809 - val_loss: 72.5178
# Epoch 49/50
#  - 0s - loss: 127.8086 - val_loss: 72.7172
# Epoch 50/50
#  - 0s - loss: 125.4360 - val_loss: 73.1753
#
# Number of time:  17
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 125.2917 - val_loss: 73.3452
# Epoch 2/50
#  - 0s - loss: 126.6353 - val_loss: 74.7819
# Epoch 3/50
#  - 0s - loss: 126.9444 - val_loss: 72.8129
# Epoch 4/50
#  - 0s - loss: 125.6496 - val_loss: 76.9899
# Epoch 5/50
#  - 0s - loss: 126.7354 - val_loss: 77.5517
# Epoch 6/50
#  - 0s - loss: 127.5099 - val_loss: 73.4693
# Epoch 7/50
#  - 0s - loss: 126.2358 - val_loss: 73.6682
# Epoch 8/50
#  - 0s - loss: 126.2278 - val_loss: 73.0910
# Epoch 9/50
#  - 0s - loss: 125.8607 - val_loss: 75.4893
# Epoch 10/50
#  - 0s - loss: 126.1135 - val_loss: 73.3110
# Epoch 11/50
#  - 0s - loss: 126.2228 - val_loss: 72.9398
# Epoch 12/50
#  - 0s - loss: 124.6625 - val_loss: 74.9950
# Epoch 13/50
#  - 0s - loss: 125.6144 - val_loss: 73.7350
# Epoch 14/50
#  - 0s - loss: 125.1602 - val_loss: 73.2684
# Epoch 15/50
#  - 0s - loss: 125.3483 - val_loss: 73.5548
# Epoch 16/50
#  - 0s - loss: 125.8599 - val_loss: 74.5651
# Epoch 17/50
#  - 0s - loss: 125.4895 - val_loss: 73.6916
# Epoch 18/50
#  - 0s - loss: 125.4483 - val_loss: 73.1307
# Epoch 19/50
#  - 0s - loss: 126.3243 - val_loss: 74.9983
# Epoch 20/50
#  - 0s - loss: 125.6078 - val_loss: 76.0053
# Epoch 21/50
#  - 0s - loss: 127.0631 - val_loss: 74.4980
# Epoch 22/50
#  - 0s - loss: 126.5036 - val_loss: 73.0924
# Epoch 23/50
#  - 0s - loss: 125.8351 - val_loss: 72.9301
# Epoch 24/50
#  - 0s - loss: 125.4247 - val_loss: 73.1413
# Epoch 25/50
#  - 0s - loss: 125.2920 - val_loss: 73.3865
# Epoch 26/50
#  - 0s - loss: 127.8775 - val_loss: 73.6028
# Epoch 27/50
#  - 0s - loss: 125.4570 - val_loss: 72.8983
# Epoch 28/50
#  - 0s - loss: 126.9434 - val_loss: 76.7008
# Epoch 29/50
#  - 0s - loss: 126.6477 - val_loss: 72.9191
# Epoch 30/50
#  - 0s - loss: 129.0321 - val_loss: 75.6025
# Epoch 31/50
#  - 0s - loss: 126.6687 - val_loss: 73.2331
# Epoch 32/50
#  - 0s - loss: 124.9199 - val_loss: 73.7062
# Epoch 33/50
#  - 0s - loss: 125.8725 - val_loss: 73.9408
# Epoch 34/50
#  - 0s - loss: 126.4176 - val_loss: 74.5648
# Epoch 35/50
#  - 0s - loss: 126.1754 - val_loss: 77.1511
# Epoch 36/50
#  - 0s - loss: 126.5340 - val_loss: 79.9326
# Epoch 37/50
#  - 0s - loss: 126.9518 - val_loss: 73.8885
# Epoch 38/50
#  - 0s - loss: 125.2978 - val_loss: 73.2731
# Epoch 39/50
#  - 0s - loss: 125.3930 - val_loss: 76.4733
# Epoch 40/50
#  - 0s - loss: 126.9687 - val_loss: 76.3969
# Epoch 41/50
#  - 0s - loss: 127.3748 - val_loss: 73.9586
# Epoch 42/50
#  - 0s - loss: 128.4464 - val_loss: 74.2520
# Epoch 43/50
#  - 0s - loss: 125.5572 - val_loss: 75.6620
# Epoch 44/50
#  - 0s - loss: 125.0758 - val_loss: 74.3907
# Epoch 45/50
#  - 0s - loss: 125.9222 - val_loss: 73.1473
# Epoch 46/50
#  - 0s - loss: 125.6850 - val_loss: 73.0560
# Epoch 47/50
#  - 0s - loss: 127.7383 - val_loss: 74.2898
# Epoch 48/50
#  - 0s - loss: 126.1631 - val_loss: 74.6731
# Epoch 49/50
#  - 0s - loss: 127.5641 - val_loss: 74.1245
# Epoch 50/50
#  - 0s - loss: 125.7819 - val_loss: 73.0343
#
# Number of time:  18
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 125.3359 - val_loss: 75.0376
# Epoch 2/50
#  - 0s - loss: 127.4866 - val_loss: 75.5374
# Epoch 3/50
#  - 0s - loss: 124.5917 - val_loss: 74.1100
# Epoch 4/50
# ...
#  - 0s - loss: 49.1025 - val_loss: 70.9024
# Epoch 11/50
#  - 0s - loss: 48.5849 - val_loss: 76.7467
# Epoch 12/50
#  - 0s - loss: 48.1847 - val_loss: 86.1290
# Epoch 13/50
#  - 0s - loss: 48.2663 - val_loss: 69.9718
# Epoch 14/50
#  - 0s - loss: 48.4934 - val_loss: 61.7304
# Epoch 15/50
#  - 0s - loss: 48.7966 - val_loss: 66.3862
# Epoch 16/50
#  - 0s - loss: 49.0391 - val_loss: 77.8271
# Epoch 17/50
#  - 0s - loss: 48.6653 - val_loss: 81.5521
# Epoch 18/50
#  - 0s - loss: 48.3857 - val_loss: 75.9632
# Epoch 19/50
#  - 0s - loss: 48.9023 - val_loss: 74.9730
# Epoch 20/50
#  - 0s - loss: 49.1933 - val_loss: 68.8599
# Epoch 21/50
#  - 0s - loss: 49.6325 - val_loss: 86.0726
# Epoch 22/50
#  - 0s - loss: 49.7709 - val_loss: 69.6594
# Epoch 23/50
#  - 0s - loss: 48.5510 - val_loss: 86.6628
# Epoch 24/50
#  - 0s - loss: 49.0559 - val_loss: 66.3501
# Epoch 25/50
#  - 0s - loss: 48.7606 - val_loss: 77.7535
# Epoch 26/50
#  - 0s - loss: 48.4656 - val_loss: 72.2481
# Epoch 27/50
#  - 0s - loss: 48.3678 - val_loss: 70.1842
# Epoch 28/50
#  - 0s - loss: 48.4961 - val_loss: 71.9304
# Epoch 29/50
#  - 0s - loss: 48.5467 - val_loss: 69.8580
# Epoch 30/50
#  - 0s - loss: 48.6330 - val_loss: 75.2097
# Epoch 31/50
#  - 0s - loss: 48.6606 - val_loss: 74.0849
# Epoch 32/50
#  - 0s - loss: 48.1014 - val_loss: 76.9149
# Epoch 33/50
#  - 0s - loss: 48.0110 - val_loss: 80.8511
# Epoch 34/50
#  - 0s - loss: 48.2808 - val_loss: 70.7830
# Epoch 35/50
#  - 0s - loss: 48.6391 - val_loss: 70.3632
# Epoch 36/50
#  - 0s - loss: 48.2235 - val_loss: 72.2764
# Epoch 37/50
#  - 0s - loss: 48.9005 - val_loss: 85.3311
# Epoch 38/50
#  - 0s - loss: 49.4954 - val_loss: 98.7800
# Epoch 39/50
#  - 0s - loss: 51.0517 - val_loss: 91.0305
# Epoch 40/50
#  - 0s - loss: 48.4755 - val_loss: 65.5497
# Epoch 41/50
#  - 0s - loss: 48.1250 - val_loss: 76.2785
# Epoch 42/50
#  - 0s - loss: 48.4871 - val_loss: 67.1193
# Epoch 43/50
#  - 0s - loss: 48.1509 - val_loss: 80.1165
# Epoch 44/50
#  - 0s - loss: 48.3571 - val_loss: 71.3474
# Epoch 45/50
#  - 0s - loss: 48.0531 - val_loss: 90.0545
# Epoch 46/50
#  - 0s - loss: 49.3726 - val_loss: 76.3741
# Epoch 47/50
#  - 0s - loss: 48.3581 - val_loss: 67.2837
# Epoch 48/50
#  - 0s - loss: 48.1827 - val_loss: 82.2269
# Epoch 49/50
#  - 0s - loss: 48.4781 - val_loss: 83.7472
# Epoch 50/50
#  - 0s - loss: 49.1768 - val_loss: 77.5016
#
# Number of time:  46
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 48.0552 - val_loss: 77.8645
# Epoch 2/50
#  - 0s - loss: 48.5701 - val_loss: 64.8902
# Epoch 3/50
#  - 0s - loss: 50.0625 - val_loss: 68.9847
# Epoch 4/50
#  - 0s - loss: 48.7414 - val_loss: 80.6831
# Epoch 5/50
#  - 0s - loss: 48.1821 - val_loss: 73.5266
# Epoch 6/50
#  - 0s - loss: 48.0207 - val_loss: 73.7595
# Epoch 7/50
#  - 0s - loss: 51.6299 - val_loss: 95.5279
# Epoch 8/50
#  - 0s - loss: 48.4555 - val_loss: 88.7664
# Epoch 9/50
#  - 0s - loss: 48.5066 - val_loss: 67.6318
# Epoch 10/50
#  - 0s - loss: 49.5301 - val_loss: 84.9107
# Epoch 11/50
#  - 0s - loss: 49.7346 - val_loss: 83.3368
# Epoch 12/50
#  - 0s - loss: 48.3319 - val_loss: 64.1461
# Epoch 13/50
#  - 0s - loss: 49.0367 - val_loss: 101.6163
# Epoch 14/50
#  - 0s - loss: 49.4099 - val_loss: 74.1515
# Epoch 15/50
#  - 0s - loss: 48.7779 - val_loss: 89.3780
# Epoch 16/50
#  - 0s - loss: 48.5301 - val_loss: 85.1460
# Epoch 17/50
#  - 0s - loss: 48.8787 - val_loss: 64.4275
# Epoch 18/50
#  - 0s - loss: 48.8576 - val_loss: 69.6211
# Epoch 19/50
#  - 0s - loss: 48.8249 - val_loss: 81.6142
# Epoch 20/50
#  - 0s - loss: 48.7078 - val_loss: 64.8890
# Epoch 21/50
#  - 0s - loss: 49.0283 - val_loss: 59.3348
# Epoch 22/50
#  - 0s - loss: 48.9573 - val_loss: 78.5774
# Epoch 23/50
#  - 0s - loss: 48.9158 - val_loss: 94.4604
# Epoch 24/50
#  - 0s - loss: 49.3444 - val_loss: 71.3841
# Epoch 25/50
#  - 0s - loss: 48.0389 - val_loss: 85.8405
# Epoch 26/50
#  - 0s - loss: 47.9582 - val_loss: 70.9761
# Epoch 27/50
#  - 0s - loss: 48.2952 - val_loss: 82.6043
# Epoch 28/50
#  - 0s - loss: 48.9547 - val_loss: 91.2953
# Epoch 29/50
#  - 0s - loss: 49.8050 - val_loss: 70.1788
# Epoch 30/50
#  - 0s - loss: 48.6054 - val_loss: 72.4898
# Epoch 31/50
#  - 0s - loss: 47.9816 - val_loss: 87.3018
# Epoch 32/50
#  - 0s - loss: 49.7092 - val_loss: 73.1690
# Epoch 33/50
#  - 0s - loss: 47.8112 - val_loss: 84.6157
# Epoch 34/50
#  - 0s - loss: 48.3570 - val_loss: 79.9950
# Epoch 35/50
#  - 0s - loss: 47.9787 - val_loss: 71.4621
# Epoch 36/50
#  - 0s - loss: 48.1250 - val_loss: 74.3719
# Epoch 37/50
#  - 0s - loss: 48.2759 - val_loss: 79.5918
# Epoch 38/50
#  - 0s - loss: 49.0342 - val_loss: 80.7846
# Epoch 39/50
#  - 0s - loss: 49.5888 - val_loss: 77.6056
# Epoch 40/50
#  - 0s - loss: 48.5725 - val_loss: 82.1562
# Epoch 41/50
#  - 0s - loss: 48.8259 - val_loss: 67.4747
# Epoch 42/50
#  - 0s - loss: 50.3827 - val_loss: 74.0787
# Epoch 43/50
#  - 0s - loss: 48.7719 - val_loss: 63.8658
# Epoch 44/50
#  - 0s - loss: 49.0671 - val_loss: 73.6622
# Epoch 45/50
#  - 0s - loss: 48.3670 - val_loss: 88.8168
# Epoch 46/50
#  - 0s - loss: 49.1764 - val_loss: 69.9283
# Epoch 47/50
#  - 0s - loss: 48.6849 - val_loss: 86.5980
# Epoch 48/50
#  - 0s - loss: 48.9152 - val_loss: 69.0025
# Epoch 49/50
#  - 0s - loss: 48.3511 - val_loss: 70.3130
# Epoch 50/50
#  - 0s - loss: 48.7753 - val_loss: 76.6043
#
# Number of time:  47
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 48.4960 - val_loss: 81.1102
# Epoch 2/50
#  - 0s - loss: 48.4839 - val_loss: 76.2149
# Epoch 3/50
#  - 0s - loss: 49.6133 - val_loss: 84.4532
# Epoch 4/50
#  - 0s - loss: 48.7608 - val_loss: 67.5829
# Epoch 5/50
#  - 0s - loss: 48.4433 - val_loss: 72.4540
# Epoch 6/50
#  - 0s - loss: 48.4395 - val_loss: 61.4177
# Epoch 7/50
#  - 0s - loss: 50.6158 - val_loss: 67.5375
# Epoch 8/50
#  - 0s - loss: 48.2458 - val_loss: 79.2097
# Epoch 9/50
#  - 0s - loss: 48.4321 - val_loss: 81.8424
# Epoch 10/50
#  - 0s - loss: 48.5485 - val_loss: 74.4525
# Epoch 11/50
#  - 0s - loss: 48.8720 - val_loss: 96.4820
# Epoch 12/50
#  - 0s - loss: 48.9175 - val_loss: 78.7354
# Epoch 13/50
#  - 0s - loss: 48.3170 - val_loss: 84.8492
# Epoch 14/50
#  - 0s - loss: 48.1715 - val_loss: 91.9360
# Epoch 15/50
#  - 0s - loss: 49.7217 - val_loss: 87.3710
# Epoch 16/50
#  - 0s - loss: 48.3326 - val_loss: 81.7963
# Epoch 17/50
#  - 0s - loss: 48.8695 - val_loss: 97.1784
# Epoch 18/50
#  - 0s - loss: 50.9912 - val_loss: 69.7985
# Epoch 19/50
#  - 0s - loss: 48.8719 - val_loss: 75.1483
# Epoch 20/50
#  - 0s - loss: 48.3673 - val_loss: 95.4981
# Epoch 21/50
#  - 0s - loss: 48.5585 - val_loss: 84.6866
# Epoch 22/50
#  - 0s - loss: 50.8424 - val_loss: 87.6935
# Epoch 23/50
#  - 0s - loss: 48.7632 - val_loss: 61.5367
# Epoch 24/50
#  - 0s - loss: 51.2160 - val_loss: 75.9807
# Epoch 25/50
#  - 0s - loss: 49.6521 - val_loss: 77.6689
# Epoch 26/50
#  - 0s - loss: 48.2933 - val_loss: 78.9096
# Epoch 27/50
#  - 0s - loss: 49.2962 - val_loss: 64.3451
# Epoch 28/50
#  - 0s - loss: 49.9541 - val_loss: 88.5270
# Epoch 29/50
#  - 0s - loss: 49.3774 - val_loss: 76.1076
# Epoch 30/50
#  - 0s - loss: 48.7590 - val_loss: 68.9441
# Epoch 31/50
#  - 0s - loss: 48.7526 - val_loss: 69.6351
# Epoch 32/50
#  - 0s - loss: 50.2200 - val_loss: 78.3258
# Epoch 33/50
#  - 0s - loss: 48.7117 - val_loss: 84.2722
# Epoch 34/50
#  - 0s - loss: 48.2338 - val_loss: 83.4601
# Epoch 35/50
#  - 0s - loss: 48.2238 - val_loss: 71.0943
# Epoch 36/50
#  - 0s - loss: 48.7021 - val_loss: 82.8691
# Epoch 37/50
#  - 0s - loss: 48.2883 - val_loss: 78.8914
# Epoch 38/50
#  - 0s - loss: 48.4912 - val_loss: 72.5332
# Epoch 39/50
#  - 0s - loss: 48.2194 - val_loss: 82.0778
# Epoch 40/50
#  - 0s - loss: 48.2258 - val_loss: 70.5926
# Epoch 41/50
#  - 0s - loss: 48.9238 - val_loss: 76.5991
# Epoch 42/50
#  - 0s - loss: 47.9774 - val_loss: 87.2707
# Epoch 43/50
#  - 0s - loss: 50.1169 - val_loss: 71.9944
# Epoch 44/50
#  - 0s - loss: 50.1653 - val_loss: 65.1429
# Epoch 45/50
#  - 0s - loss: 48.8148 - val_loss: 76.2100
# Epoch 46/50
#  - 0s - loss: 48.0334 - val_loss: 76.1697
# Epoch 47/50
#  - 0s - loss: 48.1474 - val_loss: 75.8396
# Epoch 48/50
#  - 0s - loss: 47.9572 - val_loss: 68.5996
# Epoch 49/50
#  - 0s - loss: 50.0996 - val_loss: 85.9940
# Epoch 50/50
#  - 0s - loss: 49.0286 - val_loss: 80.0755
#
# Number of time:  48
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 48.4916 - val_loss: 75.8745
# Epoch 2/50
#  - 0s - loss: 48.7114 - val_loss: 77.2803
# Epoch 3/50
#  - 0s - loss: 47.8888 - val_loss: 68.2353
# Epoch 4/50
#  - 0s - loss: 48.3834 - val_loss: 88.3485
# Epoch 5/50
#  - 0s - loss: 50.0924 - val_loss: 66.1803
# Epoch 6/50
#  - 0s - loss: 47.9954 - val_loss: 94.6491
# Epoch 7/50
#  - 0s - loss: 48.3795 - val_loss: 83.0390
# Epoch 8/50
#  - 0s - loss: 48.5137 - val_loss: 74.7169
# Epoch 9/50
#  - 0s - loss: 48.8694 - val_loss: 66.9464
# Epoch 10/50
#  - 0s - loss: 49.3794 - val_loss: 76.2941
# Epoch 11/50
#  - 0s - loss: 48.3443 - val_loss: 65.5008
# Epoch 12/50
#  - 0s - loss: 49.2230 - val_loss: 67.5435
# Epoch 13/50
#  - 0s - loss: 48.2114 - val_loss: 64.4041
# Epoch 14/50
#  - 0s - loss: 50.3201 - val_loss: 90.7395
# Epoch 15/50
#  - 0s - loss: 49.4794 - val_loss: 104.7896
# Epoch 16/50
#  - 0s - loss: 52.2735 - val_loss: 70.9590
# Epoch 17/50
#  - 0s - loss: 48.4228 - val_loss: 70.7910
# Epoch 18/50
#  - 0s - loss: 48.3848 - val_loss: 79.2860
# Epoch 19/50
#  - 0s - loss: 48.2236 - val_loss: 82.8258
# Epoch 20/50
#  - 0s - loss: 48.7061 - val_loss: 76.5661
# Epoch 21/50
#  - 0s - loss: 49.8501 - val_loss: 58.4768
# Epoch 22/50
#  - 0s - loss: 51.1602 - val_loss: 67.3236
# Epoch 23/50
#  - 0s - loss: 49.0309 - val_loss: 83.6528
# Epoch 24/50
#  - 0s - loss: 49.6305 - val_loss: 91.4133
# Epoch 25/50
#  - 0s - loss: 49.8399 - val_loss: 76.5792
# Epoch 26/50
#  - 0s - loss: 47.9742 - val_loss: 73.5376
# Epoch 27/50
#  - 0s - loss: 49.1407 - val_loss: 69.4861
# Epoch 28/50
#  - 0s - loss: 51.8788 - val_loss: 96.5948
# Epoch 29/50
#  - 0s - loss: 49.6866 - val_loss: 92.9414
# Epoch 30/50
#  - 0s - loss: 50.3475 - val_loss: 70.6416
# Epoch 31/50
#  - 0s - loss: 48.9795 - val_loss: 71.0296
# Epoch 32/50
#  - 0s - loss: 48.3530 - val_loss: 74.7938
# Epoch 33/50
#  - 0s - loss: 48.3927 - val_loss: 73.2225
# Epoch 34/50
#  - 0s - loss: 48.4048 - val_loss: 87.7041
# Epoch 35/50
#  - 0s - loss: 49.1001 - val_loss: 72.2181
# Epoch 36/50
#  - 0s - loss: 49.5034 - val_loss: 65.1924
# Epoch 37/50
#  - 0s - loss: 48.3323 - val_loss: 73.5962
# Epoch 38/50
#  - 0s - loss: 47.8420 - val_loss: 96.1232
# Epoch 39/50
#  - 0s - loss: 51.3050 - val_loss: 83.6256
# Epoch 40/50
#  - 0s - loss: 49.0249 - val_loss: 81.1199
# Epoch 41/50
#  - 0s - loss: 48.4641 - val_loss: 93.0847
# Epoch 42/50
#  - 0s - loss: 49.1104 - val_loss: 81.6299
# Epoch 43/50
#  - 0s - loss: 48.1828 - val_loss: 69.9644
# Epoch 44/50
#  - 0s - loss: 48.8363 - val_loss: 79.4411
# Epoch 45/50
#  - 0s - loss: 48.5882 - val_loss: 59.5363
# Epoch 46/50
#  - 0s - loss: 49.0913 - val_loss: 67.6558
# Epoch 47/50
#  - 0s - loss: 48.5569 - val_loss: 75.5985
# Epoch 48/50
#  - 0s - loss: 47.9503 - val_loss: 66.4350
# Epoch 49/50
#  - 0s - loss: 49.9812 - val_loss: 80.8059
# Epoch 50/50
#  - 0s - loss: 48.4631 - val_loss: 81.1891
#
# Number of time:  49
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 48.0396 - val_loss: 79.8866
# Epoch 2/50
#  - 0s - loss: 48.3330 - val_loss: 64.7842
# Epoch 3/50
#  - 0s - loss: 48.3019 - val_loss: 64.9060
# Epoch 4/50
#  - 0s - loss: 48.1296 - val_loss: 84.3001
# Epoch 5/50
#  - 0s - loss: 48.2533 - val_loss: 77.5861
# Epoch 6/50
#  - 0s - loss: 48.2245 - val_loss: 66.0813
# Epoch 7/50
#  - 0s - loss: 48.0877 - val_loss: 75.6401
# Epoch 8/50
#  - 0s - loss: 48.0200 - val_loss: 75.1928
# Epoch 9/50
#  - 0s - loss: 48.4388 - val_loss: 86.6388
# Epoch 10/50
#  - 0s - loss: 48.5931 - val_loss: 65.5798
# Epoch 11/50
#  - 0s - loss: 49.1949 - val_loss: 74.9323
# Epoch 12/50
#  - 0s - loss: 48.4198 - val_loss: 72.9612
# Epoch 13/50
#  - 0s - loss: 50.1033 - val_loss: 90.7504
# Epoch 14/50
#  - 0s - loss: 48.9575 - val_loss: 79.7253
# Epoch 15/50
#  - 0s - loss: 49.0821 - val_loss: 80.0642
# Epoch 16/50
#  - 0s - loss: 48.2228 - val_loss: 82.2019
# Epoch 17/50
#  - 0s - loss: 49.6468 - val_loss: 84.2298
# Epoch 18/50
#  - 0s - loss: 48.1032 - val_loss: 76.3567
# Epoch 19/50
#  - 0s - loss: 48.2519 - val_loss: 72.4049
# Epoch 20/50
#  - 0s - loss: 48.4535 - val_loss: 85.3037
# Epoch 21/50
#  - 0s - loss: 49.8571 - val_loss: 73.4427
# Epoch 22/50
#  - 0s - loss: 48.7935 - val_loss: 75.0385
# Epoch 23/50
#  - 0s - loss: 48.4462 - val_loss: 89.2107
# Epoch 24/50
#  - 0s - loss: 48.6720 - val_loss: 67.3538
# Epoch 25/50
#  - 0s - loss: 49.6246 - val_loss: 72.4197
# Epoch 26/50
#  - 0s - loss: 47.9055 - val_loss: 79.7213
# Epoch 27/50
#  - 0s - loss: 48.0723 - val_loss: 76.1438
# Epoch 28/50
#  - 0s - loss: 48.7086 - val_loss: 79.5508
# Epoch 29/50
#  - 0s - loss: 49.2270 - val_loss: 76.5607
# Epoch 30/50
#  - 0s - loss: 48.3291 - val_loss: 75.0999
# Epoch 31/50
#  - 0s - loss: 48.0485 - val_loss: 78.0323
# Epoch 32/50
#  - 0s - loss: 48.4061 - val_loss: 86.8919
# Epoch 33/50
#  - 0s - loss: 48.3995 - val_loss: 72.3909
# Epoch 34/50
#  - 0s - loss: 48.4556 - val_loss: 88.0957
# Epoch 35/50
#  - 0s - loss: 49.1128 - val_loss: 76.7131
# Epoch 36/50
#  - 0s - loss: 47.9735 - val_loss: 71.8811
# Epoch 37/50
#  - 0s - loss: 48.8073 - val_loss: 89.4708
# Epoch 38/50
#  - 0s - loss: 48.1988 - val_loss: 78.9517
# Epoch 39/50
#  - 0s - loss: 48.2462 - val_loss: 80.2145
# Epoch 40/50
#  - 0s - loss: 48.8356 - val_loss: 79.4586
# Epoch 41/50
#  - 0s - loss: 48.0397 - val_loss: 66.3939
# Epoch 42/50
#  - 0s - loss: 49.5842 - val_loss: 79.2121
# Epoch 43/50
#  - 0s - loss: 48.7894 - val_loss: 66.8186
# Epoch 44/50
#  - 0s - loss: 50.3554 - val_loss: 83.7467
# Epoch 45/50
#  - 0s - loss: 48.6775 - val_loss: 89.6935
# Epoch 46/50
#  - 0s - loss: 48.3339 - val_loss: 79.1679
# Epoch 47/50
#  - 0s - loss: 48.2527 - val_loss: 72.1029
# Epoch 48/50
#  - 0s - loss: 47.9273 - val_loss: 93.9490
# Epoch 49/50
#  - 0s - loss: 48.7925 - val_loss: 78.2488
# Epoch 50/50
#  - 0s - loss: 48.3204 - val_loss: 68.3142
#
# Number of time:  50
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 0s - loss: 48.5761 - val_loss: 70.3852
# Epoch 2/50
#  - 0s - loss: 47.9001 - val_loss: 84.5751
# Epoch 3/50
#  - 0s - loss: 48.5685 - val_loss: 73.7702
# Epoch 4/50
#  - 0s - loss: 48.2718 - val_loss: 82.9640
# Epoch 5/50
#  - 0s - loss: 48.5173 - val_loss: 70.3166
# Epoch 6/50
#  - 0s - loss: 47.8374 - val_loss: 76.5858
# Epoch 7/50
#  - 0s - loss: 48.2152 - val_loss: 73.5009
# Epoch 8/50
#  - 0s - loss: 48.9500 - val_loss: 69.1197
# Epoch 9/50
#  - 0s - loss: 48.5220 - val_loss: 79.4940
# Epoch 10/50
#  - 0s - loss: 48.4032 - val_loss: 76.4133
# Epoch 11/50
#  - 0s - loss: 48.8406 - val_loss: 67.3575
# Epoch 12/50
#  - 0s - loss: 48.4624 - val_loss: 73.6754
# Epoch 13/50
#  - 0s - loss: 48.1105 - val_loss: 76.3880
# Epoch 14/50
#  - 0s - loss: 48.3210 - val_loss: 83.0283
# Epoch 15/50
#  - 0s - loss: 48.6234 - val_loss: 78.3705
# Epoch 16/50
#  - 0s - loss: 48.2411 - val_loss: 72.2067
# Epoch 17/50
#  - 0s - loss: 48.2021 - val_loss: 85.5205
# Epoch 18/50
#  - 0s - loss: 49.5951 - val_loss: 93.5617
# Epoch 19/50
#  - 0s - loss: 47.9477 - val_loss: 74.5393
# Epoch 20/50
#  - 0s - loss: 48.8089 - val_loss: 95.7009
# Epoch 21/50
#  - 0s - loss: 49.1251 - val_loss: 79.3149
# Epoch 22/50
#  - 0s - loss: 47.8072 - val_loss: 65.3775
# Epoch 23/50
#  - 0s - loss: 48.8828 - val_loss: 61.5969
# Epoch 24/50
#  - 0s - loss: 48.9628 - val_loss: 73.8968
# Epoch 25/50
#  - 0s - loss: 48.4063 - val_loss: 79.9850
# Epoch 26/50
#  - 0s - loss: 48.2757 - val_loss: 62.1406
# Epoch 27/50
#  - 0s - loss: 49.5024 - val_loss: 70.0759
# Epoch 28/50
#  - 0s - loss: 48.5854 - val_loss: 88.1664
# Epoch 29/50
#  - 0s - loss: 48.1905 - val_loss: 89.7882
# Epoch 30/50
#  - 0s - loss: 49.0245 - val_loss: 96.0381
# Epoch 31/50
#  - 0s - loss: 50.5857 - val_loss: 62.9924
# Epoch 32/50
#  - 0s - loss: 49.8188 - val_loss: 69.8912
# Epoch 33/50
#  - 0s - loss: 48.6433 - val_loss: 79.8689
# Epoch 34/50
#  - 0s - loss: 47.9374 - val_loss: 74.8579
# Epoch 35/50
#  - 0s - loss: 48.1810 - val_loss: 78.6692
# Epoch 36/50
#  - 0s - loss: 48.3628 - val_loss: 79.8345
# Epoch 37/50
#  - 0s - loss: 47.7710 - val_loss: 90.4917
# Epoch 38/50
#  - 0s - loss: 49.1109 - val_loss: 69.1311
# Epoch 39/50
#  - 0s - loss: 49.5424 - val_loss: 68.8294
# Epoch 40/50
#  - 0s - loss: 48.1284 - val_loss: 76.3289
# Epoch 41/50
#  - 0s - loss: 48.2365 - val_loss: 84.0141
# Epoch 42/50
#  - 0s - loss: 48.5853 - val_loss: 63.8347
# Epoch 43/50
#  - 0s - loss: 48.5738 - val_loss: 72.5765
# Epoch 44/50
#  - 0s - loss: 48.0199 - val_loss: 95.9606
# Epoch 45/50
#  - 0s - loss: 49.6859 - val_loss: 92.4838
# Epoch 46/50
#  - 0s - loss: 49.4031 - val_loss: 72.2599
# Epoch 47/50
#  - 0s - loss: 49.4523 - val_loss: 66.4576
# Epoch 48/50
#  - 0s - loss: 48.5414 - val_loss: 65.3355
# Epoch 49/50
#  - 0s - loss: 48.5438 - val_loss: 80.6507
# Epoch 50/50
#  - 0s - loss: 48.2637 - val_loss: 79.6009

# %% [markdown]
# ## 5. Report the mean and the standard deviation of the mean squared errors.

# %%
mean = np.mean(l)
std = np.std(l)

print("Mean: ", mean)
print("Standard Deviation: ", std)
# Out:
# Mean:  95.00060315109855
# Standard Deviation:  31.552997563895342

# %% [markdown]
# This notebook is part of a course on **Coursera** called _Introduction to Deep Learning & Neural Networks with Keras_
